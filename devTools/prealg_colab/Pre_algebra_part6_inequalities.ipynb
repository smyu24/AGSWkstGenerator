# %% [markdown]
# #Part 6 Inequalities

# %% [markdown]
# ## Graphing single-variable inequalities
# ### Instruction : Draw a graph for each inequality.
#
# #### section 1
#
# ---
#
# intA = -10 to 10
#
# fracA = $\frac{int(1-10)}{int(1-10)}$
#
# fracB = $ int(-10 to 10) \frac{int(1-10)}{int(1-10)}$
#
# sign = ['<' , '>' , '\geq' , '\leq']
#
# ---
#
# -  easy
#   - case 1
#   - x  sign  intA
#   - $ x > 5$
#
# -  medium
#   - case 1
#   - $\pm$ x sign intA
#   - $ \pm x \geq 5$
#   - case 2
#   - -x sign fracA
#   - $ \pm x \geq \frac{2}{7}$
#
# -  hard
#   - case 1
#   - x sign fracB
#   - $ x \geq -3\frac{2}{7}$
#   - case 2
#   - $\pm $ x sign fracB
#   - $ -x \geq -3\frac{2}{7}$
#
#
# #### section 2
# ---
# Instruction : Write an inequality for each graph.
#
# one way, open ended
#
# need to construct

# %%
import random, fractions

def fraction_generator(option_difficulty):
    problem = ""
    numerator = 4
    denominator = 4
    while float(numerator % denominator) == 0:
        numerator = random.randint(2, 100)
        denominator = random.randint(2, 100)
        problem = fractions.Fraction(numerator, denominator)
    return(problem)
for i in range(10):
  print(fraction_generator("hard"))
# Out:
# 59/90
# 39/70
# 16/17
# 25/9
# 89/55
# 48/23
# 99/100
# 55/31
# 31/4
# 4/73

# %%
# First Section

import math
import random
import sympy as sp
import fractions

def Whole_Inequality_Graph_Template(line_length, symbol):
    line_length = int(line_length)
    number_line_size = -7 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 4 #plus minus 4
    while (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 3
        elif (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 3

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (14,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    out.append(r'\foreach \x in {1,2,...,13}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')
    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (14,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    copy.append(r'\foreach \x in {1,2,...,13}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    #out.append(fr'{$\scriptstyle \the\numexpr-{number_line_size}+1*\x\relax$};)')-7 + 1*
    #out.append(r"{}{}{}".format('{$\scriptstyle \the\numexpr-', str(number_line_size), '+1*\x\relax$};)'))
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (12,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (12,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))


def Decimal_Inequality_Graph_Template(line_length, symbol):
    line_length = float(line_length)
    number_line_size = -2 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 1 #plus minus 4
    while (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 1
        elif (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 1

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (7,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    out.append(r'\foreach \x in {1,2,...,6}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')

    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (7,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    copy.append(r'\foreach \x in {1,2,...,6}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (7,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (7,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))


def else_situation(sym_1):    
    if sym_1 == '<':
        sym_1 = '>'
        return(sym_1)
    elif sym_1 == '>':
        sym_1 = '<'
        return(sym_1)
    elif sym_1 == '>=':
        sym_1 = '<='
        return(sym_1)
    elif sym_1 == '<=':
        sym_1 = '>='
        return(sym_1)


def Graphing_One_Variable_Inequalities_1(option_difficulty, option_random):
    problemsets = []
    answerset = []
    another = []
    choices = ['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v']
    negative = ['-', '']
    sym_1 = ''
    variables = []
    numerals = []
    equation = ''
    receivant = ""
    inequal_symbols = ['>', '<', '>=', '<=']
    if option_difficulty == "easy": # greater/less than or equal to included (positive variables and number range from -5 to 5)
        variables.append(random.choice(choices))
        sym_1 = random.choice(inequal_symbols)
        numerals.append(str(random.choice(negative)) + str(random.randint(1, 5)))

        x = sp.symbols(variables[0])

        if random.randint(1,2) == 1:
            equation = '{} {} {}'.format(variables[0], str(sym_1) , str(numerals[0]))
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            receivant = Whole_Inequality_Graph_Template(numerals[0], sym_1)
            answerset.append(receivant[0])
            another.append(receivant[1])
        else:
            equation = '{} {} {}'.format(str(numerals[0]), str(sym_1), variables[0])
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            receivant = Whole_Inequality_Graph_Template(numerals[0], else_situation(sym_1))
            answerset.append(receivant[0])
            another.append(receivant[1])

    elif option_difficulty == "medium": # greater/less than or equal to included, but with a greater number threshhold and possibility of negative variables
        if str(random.choice(negative)) == '-':
            variables.append('-' + str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            filler = str(random.choice(negative)) + str(random.randint(1, 10))
            numerals.append(int(filler))
            if random.randint(1,2) == 1:
                equation = '{} {} {}'.format(variables[0], str(sym_1) , str(numerals[0]))
                sym_1 = else_situation(sym_1)
                numerals[0] = int(filler) * -1
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Whole_Inequality_Graph_Template(numerals[0], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {}'.format(str(numerals[0]), str(sym_1), variables[0])
                sym_1 = else_situation(sym_1)
                numerals[0] = int(filler) * -1
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Whole_Inequality_Graph_Template(numerals[0], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
        else:
            variables.append(str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            numerals.append(str(random.choice(negative)) + str(random.randint(1, 10)))
            if random.randint(1,2) == 1:
                equation = '{} {} {}'.format(variables[0], str(sym_1) , str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Whole_Inequality_Graph_Template(numerals[0], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {}'.format(str(numerals[0]), str(sym_1), variables[0])
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Whole_Inequality_Graph_Template(numerals[0], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
    
    elif option_difficulty == "hard": # fraction (mixed?)
        if str(random.choice(negative)) == '-':
            variables.append('-' + str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            filler = str(random.choice(negative)) + str(random.randint(1, 10)) + "." + str(random.randint(1,99))
            numerals.append(float(filler))
            if random.randint(1,2) == 1:
                equation = '{} {} {}'.format(variables[0], str(sym_1) , str(numerals[0]))
                sym_1 = else_situation(sym_1)
                numerals[0] = float(filler) * -1
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Decimal_Inequality_Graph_Template(numerals[0], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {}'.format(str(numerals[0]), str(sym_1), variables[0])
                sym_1 = else_situation(sym_1)
                numerals[0] = float(filler) * -1
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Decimal_Inequality_Graph_Template(numerals[0], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
        else:
            variables.append(str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            numerals.append(str(random.choice(negative)) + str(random.randint(1, 10)) + "." + str(random.randint(1,99)))
            if random.randint(1,2) == 1:
                equation = '{} {} {}'.format(variables[0], str(sym_1) , str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Decimal_Inequality_Graph_Template(numerals[0], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {}'.format(str(numerals[0]), str(sym_1), variables[0])
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                receivant = Decimal_Inequality_Graph_Template(numerals[0], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
            
            
    return(problemsets[0], answerset[0], another[0])
    
for i in range(1):
    a,b,c = Graphing_One_Variable_Inequalities_1("easy", False)
    print(a, '\n',b, '\n', c)
for i in range(1):
    a,b,c = Graphing_One_Variable_Inequalities_1("medium", False)
    print(a, '\n',b, '\n', c)
for i in range(1):
    a,b,c = Graphing_One_Variable_Inequalities_1("hard", False)
    print(a, '\n',b, '\n', c)
# Out:
# $5 \leq r$
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\draw[->,very thick,red,-latex] (9,0) -- (12,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture}
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\end{tikzpicture}
# $-8 \leq - v$
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture}
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# $-6.52 > - s$
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr4 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.5199999999999996, 0) -- (7,0);\draw[red, fill=white, thick] (2.5199999999999996,0) circle (-2pt);\end{tikzpicture}
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr4 + 1*\x\relax$};\end{tikzpicture}

# %%
\documentclass[letterpaper,12pt]{book}
\usepackage{tikz}
\begin{document}
\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]
  \clip (0,-0.8) rectangle (10,1);
  %   Inequality Line
  \draw   [<->,thick]     (0,0) -- (10,0);
  %   Tick Marks
  \foreach \x in {1,2,...,9}
  \draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]
  {$\scriptstyle \the\numexpr0+1*\x\relax$};
  %   Displayed Solution
\end{tikzpicture}
\end{document}

# %% [markdown]
# ## Solving One-Step Inequalities by Adding/Subtracting
# ### Instruction : Solve each inequality and graph its solution.
#
# #### section 1
#
# ---
#
# intA = 2 to 20
# intB = -20 to 20
#
# fracA = $\frac{int(1-10)}{int(1-10)}$
#
# fracB = $ int(-10 to 10) \frac{int(1-10)}{int(1-10)}$
#
# sign = ['<' , '>' , '\geq' , '\leq']
#
# ---
#
# -  easy (1 to 5) num range
#   - case 1
#   - $ x − 1 > 6 $
#
# -  medium (1 to 10) num range
#   - case 1
#   - $ - x - 14 > -12$
#
# -  hard (10 to 30) num range
#   - case 1
#   - $-n − 20 > 30$

# %%
# First Section

import math
import random
import sympy as sp
import fractions

def Whole_Inequality_Graph_Template(line_length, symbol):
    line_length = int(line_length)
    number_line_size = -7 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 4 #plus minus 4
    while (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 3
        elif (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 3

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (14,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    out.append(r'\foreach \x in {1,2,...,13}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')
    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (14,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    copy.append(r'\foreach \x in {1,2,...,13}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    #out.append(fr'{$\scriptstyle \the\numexpr-{number_line_size}+1*\x\relax$};)')-7 + 1*
    #out.append(r"{}{}{}".format('{$\scriptstyle \the\numexpr-', str(number_line_size), '+1*\x\relax$};)'))
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (12,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (12,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))

def else_situation(sym_1):    
    if sym_1 == '<':
        sym_1 = '>'
        return(sym_1)
    elif sym_1 == '>':
        sym_1 = '<'
        return(sym_1)
    elif sym_1 == '>=':
        sym_1 = '<='
        return(sym_1)
    elif sym_1 == '<=':
        sym_1 = '>='
        return(sym_1)

def Solving_One_Step_Inequalities_Adding_Subtracting(option_difficulty = 'easy', expr = 'latex'):
    problemsets = []
    answerset = []
    another = []
    choices = ['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v']
    addition_expression = ['+', '-']
    negative = ['-', '']
    sym_1 = ''
    sym_1 = ''
    variables = []
    numerals = []
    equation = ''
    ran = 0
    receivant = ""
    inequal_symbols = ['>', '<', '>=', '<=']
    if option_difficulty == "easy": # greater/less than or equal to included (positive variables and number range from -5 to 5)  x − 1 > 6
        variables.append(random.choice(choices))
        sym_1 = random.choice(inequal_symbols)
        sym_2 = random.choice(addition_expression)
        numerals.append(str(random.randint(1, 5)))
        numerals.append(str(random.choice(negative)) + str(random.randint(1, 5)))

        x = sp.symbols(variables[0])
        
        ran = random.randint(1,4)
 
        if ran == 1:
            equation = '{} {} {} {} {}'.format(variables[0], sym_2, numerals[0], str(sym_1) , str(numerals[1]))
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            if sym_2 == '+':
                numerals[1] = int(numerals[1]) - int(numerals[0])
            else:
                numerals[1] = int(numerals[1]) + int(numerals[0])
            receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
            answerset.append(receivant[0])
            another.append(receivant[1])
        elif ran == 2:
            equation = '{} {} {} {} {}'.format(str(numerals[0]), sym_2, variables[0], str(sym_1), str(numerals[1]))
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            numerals[1] = int(numerals[1]) - int(numerals[0])
            if sym_2 == '-':
                sym_1 = else_situation(sym_1)
                numerals[1] = int(numerals[1]) * -1
            receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
            answerset.append(receivant[0])
            another.append(receivant[1])
        elif ran == 3:# inequal first
            equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), variables[0], sym_2, str(numerals[0]))
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            if sym_2 == '+':
                numerals[1] = int(numerals[1]) - int(numerals[0])
            else:
                numerals[1] = int(numerals[1]) + int(numerals[0])
            receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
            answerset.append(receivant[0])
            another.append(receivant[1])
        else:
            equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), str(numerals[0]), sym_2, variables[0])
            problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            numerals[1] = int(numerals[1]) - int(numerals[0])
            if sym_2 == '-':
                sym_1 = else_situation(sym_1)
                numerals[1] = int(numerals[1]) * -1
            receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
            answerset.append(receivant[0])
            another.append(receivant[1])


    elif option_difficulty == "medium": # greater/less than or equal to included, but with a greater number threshhold and possibility of negative variables -x−14>−12
        if str(random.choice(negative)) == '-':
            variables.append('-' + str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            sym_2 = random.choice(addition_expression)
            numerals.append(str(random.randint(1, 10)))
            numerals.append(str(random.choice(negative)) + str(random.randint(1, 10)))

            x = sp.symbols(variables[0])

            ran = random.randint(1,2)

            if ran == 1:
                equation = '{} {} {} {} {}'.format(variables[0], sym_2, numerals[0], str(sym_1) , str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * -1, else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
            else: # inequal first
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), variables[0], sym_2, str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * -1, sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
        else:
            variables.append(random.choice(choices))
            sym_1 = random.choice(inequal_symbols)
            sym_2 = random.choice(addition_expression)
            numerals.append(str(random.randint(1, 10)))
            numerals.append(str(random.choice(negative)) + str(random.randint(1, 10)))

            x = sp.symbols(variables[0])

            ran = random.randint(1,4)

   
            if ran == 1:
                equation = '{} {} {} {} {}'.format(variables[0], sym_2, numerals[0], str(sym_1) , str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            elif ran == 2:
                equation = '{} {} {} {} {}'.format(str(numerals[0]), sym_2, variables[0], str(sym_1), str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                numerals[1] = int(numerals[1]) - int(numerals[0])
                if sym_2 == '-':
                    sym_1 = else_situation(sym_1)
                    numerals[1] = int(numerals[1]) * -1
                receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            elif ran == 3:# inequal first
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), variables[0], sym_2, str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), str(numerals[0]), sym_2, variables[0])
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                numerals[1] = int(numerals[1]) - int(numerals[0])
                if sym_2 == '-':
                    sym_1 = else_situation(sym_1)
                    numerals[1] = int(numerals[1]) * -1
                receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
    
    
    elif option_difficulty == "hard": # all of the above, and some more... (larger num threshhold)
        if str(random.choice(negative)) == '-':
            variables.append('-' + str(random.choice(choices)))
            sym_1 = random.choice(inequal_symbols)
            sym_2 = random.choice(addition_expression)
            numerals.append(str(random.randint(10, 30)))
            numerals.append(str(random.choice(negative)) + str(random.randint(10, 30)))

            x = sp.symbols(variables[0])

            ran = random.randint(1,2)
 
            if ran == 1:
                equation = '{} {} {} {} {}'.format(variables[0], sym_2, numerals[0], str(sym_1) , str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * -1, else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
            else: # inequal first
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), variables[0], sym_2, str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * -1, sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
        else:
            variables.append(random.choice(choices))
            sym_1 = random.choice(inequal_symbols)
            sym_2 = random.choice(addition_expression)
            numerals.append(str(random.randint(10, 30)))
            numerals.append(str(random.choice(negative)) + str(random.randint(10, 30)))

            x = sp.symbols(variables[0])

            ran = random.randint(1,4)

            if ran == 1:
                equation = '{} {} {} {} {}'.format(variables[0], sym_2, numerals[0], str(sym_1) , str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            elif ran == 2:
                equation = '{} {} {} {} {}'.format(str(numerals[0]), sym_2, variables[0], str(sym_1), str(numerals[1]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                numerals[1] = int(numerals[1]) - int(numerals[0])
                if sym_2 == '-':
                    sym_1 = else_situation(sym_1)
                    numerals[1] = int(numerals[1]) * -1
                receivant = Whole_Inequality_Graph_Template(numerals[1], sym_1)
                answerset.append(receivant[0])
                another.append(receivant[1])
            elif ran == 3:# inequal first
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), variables[0], sym_2, str(numerals[0]))
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                if sym_2 == '+':
                    numerals[1] = int(numerals[1]) - int(numerals[0])
                else:
                    numerals[1] = int(numerals[1]) + int(numerals[0])
                receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])
            else:
                equation = '{} {} {} {} {}'.format(str(numerals[1]), str(sym_1), str(numerals[0]), sym_2, variables[0])
                problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                numerals[1] = int(numerals[1]) - int(numerals[0])
                if sym_2 == '-':
                    sym_1 = else_situation(sym_1)
                    numerals[1] = int(numerals[1]) * -1
                receivant = Whole_Inequality_Graph_Template(numerals[1], else_situation(sym_1))
                answerset.append(receivant[0])
                another.append(receivant[1])

    return(problemsets[0], answerset[0], another[0])

    
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Adding_Subtracting("easy", False)
    print(a, '\\\ \n',b, '\\\ \n', c)
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Adding_Subtracting("medium", False)
    print(a, '\\\ \n',b, '\\\ \n', c)
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Adding_Subtracting("hard", False)
    print(a, '\\\ \n',b, '\\\ \n', c)
# Out:
# $u + 1 > -1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (5, 0) -- (12,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# $-5 \leq 3 - s$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# $-4 \leq 5 - h$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# $2 - h < -7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10, 0) -- (12,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# $- h - 5 < -9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (11, 0) -- (12,0);\draw[red, fill=white, thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# $10 \geq 10 - a$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (7,0) -- (12,0);\draw[red, fill=red, very thick] (7,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# $d + 17 \leq -10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-31 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (4,0);\draw[red, fill=red, very thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-31 + 1*\x\relax$};\end{tikzpicture}
# $-15 \leq r - 26$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (9,0) -- (12,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\end{tikzpicture}
# $29 < 21 - u$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-13 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (5,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-13 + 1*\x\relax$};\end{tikzpicture}

# %% [markdown]
# ## Solving One-Step Inequalities by Multiplication/Division
# ### Instruction : Solve each inequality and graph its solution.
#
# Learning Targets Should be : Multiplication; Division; Then Mixed
#
# sign = ['<' , '>' , '\geq' , '\leq']
#
# ---
#
# -  easy (1 to 5) num range
#   - case 1
#   - $ 4x > 6 $
#
# -  medium (1 to 10) num range
#   - case 1
#   - $ \frac{t}{3} = 5 $
#
# -  hard (10 to 30) num range
#   - case 1
#   - $ \frac{a}{5} = 5 $

# %%
# First Section

import math
import random
import sympy as sp
import fractions

def Whole_Inequality_Graph_Template(line_length, symbol):
    line_length = int(line_length)
    number_line_size = -7 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 4 #plus minus 4
    while (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 3
        elif (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 3

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (14,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    out.append(r'\foreach \x in {1,2,...,13}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')
    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (14,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    copy.append(r'\foreach \x in {1,2,...,13}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    #out.append(fr'{$\scriptstyle \the\numexpr-{number_line_size}+1*\x\relax$};)')-7 + 1*
    #out.append(r"{}{}{}".format('{$\scriptstyle \the\numexpr-', str(number_line_size), '+1*\x\relax$};)'))
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (12,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (12,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))


def Decimal_Inequality_Graph_Template(line_length, symbol):
    line_length = float(line_length)
    number_line_size = -2 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 1 #plus minus 4
    while (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 1
        elif (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 1

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (7,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    out.append(r'\foreach \x in {1,2,...,6}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')

    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (7,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    copy.append(r'\foreach \x in {1,2,...,6}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (7,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (7,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))


def else_situation(sym_1):    
    if sym_1 == '<':
        sym_1 = '>'
        return(sym_1)
    elif sym_1 == '>':
        sym_1 = '<'
        return(sym_1)
    elif sym_1 == '>=':
        sym_1 = '<='
        return(sym_1)
    elif sym_1 == '<=':
        sym_1 = '>='
        return(sym_1)

def Solving_One_Step_Inequalities_Multiplication_Division(option_difficulty = 'easy', expr = 'latex'):
    problemsets = []
    answerset = []
    another = []
    choices = ['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v']
    all_expressions = ['+', '-', '*', '/']
    addition_expression = ['+', '-']
    mult_expression = ['*', '/']
    negative = ['-', '']
    sym_1 = ''
    sym_1 = ''
    variables = []
    variable_values = []
    numerals = []
    equation = ''
    receivant = ""
    inequal_symbols = ['>', '<', '>=', '<=']

    if option_difficulty == "easy": # greater/less than or equal to included (positive variables and number range from -5 to 5)  
        sym_1 = random.choice(inequal_symbols)
        sym_2 = "*"
        numerals.append(str(random.randint(2, 5)))
        numerals.append(str(random.choice(negative)) + str(random.randint(1, 5)))
        
        if str(random.choice(negative)) == '-': #if variable is negative
            variables.append('-' + str(random.choice(choices)))
            x = sp.symbols(variables[0])
            if sym_2 == '*': # var first
                if random.randint(1,2) == 1:
            
                    equation = fr'{variables[0]} * {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
              
                    if str(numerals[1])[0] == '-' and str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[1])[0] == '-': 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[0])[0] == "-":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} * {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
       
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[0] == '-' and str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[1])[0] == '-': 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[0])[0] == "-":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), ((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 

                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
            
        else:# if variable is posititive
            variables.append(random.choice(choices))
            x = sp.symbols(variables[0])
            if sym_2 == '*': # var first
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} * {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) / int(numerals[0])
          
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} * {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) / int(numerals[0])
             
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
            
    elif option_difficulty == "medium":
        sym_1 = random.choice(inequal_symbols)
        sym_2 = "/"
        numerals.append(str(random.randint(2, 5)))
        numerals.append(str(random.choice(negative)) + str(random.randint(1, 5)))
        
        if str(random.choice(negative)) == '-': #if variable is negative
      
            variables.append('-' + str(random.choice(choices)))
            x = sp.symbols(variables[0])
            if sym_2 == '/':
         
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} / {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            
                    
                    if str(numerals[1])[0] == '-': 
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else:
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} / {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
          

                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[0] == '-': 
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else:
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])

        else:# if variable is posititive
            variables.append(random.choice(choices))
            x = sp.symbols(variables[0])
            if sym_2 == '/':
           
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} / {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) * int(numerals[0])
                
                    #if ending value is not 0, the ncall on the decimal numberline
                    receivant = Whole_Inequality_Graph_Template(float(numerals[1]), sym_1)
                    answerset.append(receivant[0])
                    another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} / {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) * int(numerals[0])
               
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])

    elif option_difficulty == "hard":
        
        sym_1 = random.choice(inequal_symbols)
        sym_2 = random.choice(mult_expression)
        numerals.append(str(random.randint(2, 5)))
        numerals.append(str(random.choice(negative)) + str(random.randint(1, 5)))
        
        if str(random.choice(negative)) == '-': #if variable is negative
   
            variables.append('-' + str(random.choice(choices)))
            x = sp.symbols(variables[0])
            if sym_2 == '*': # var first
                if random.randint(1,2) == 1:
            
                    equation = fr'{variables[0]} * {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
              
                    if str(numerals[1])[0] == '-' and str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[1])[0] == '-': 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[0])[0] == "-":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} * {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                        
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[0] == '-' and str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[1])[0] == '-': 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    elif str(numerals[0])[0] == "-":
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0])), ((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) / (int(numerals[0]) * -1), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
            elif sym_2 == '/':
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} / {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
            
                    
                    if str(numerals[1])[0] == '-': 
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), else_situation((sym_1)))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else:
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} / {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
          

                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[0] == '-': 
                        receivant = Whole_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), (sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else:
                        receivant = Decimal_Inequality_Graph_Template(int(numerals[1]) * (int(numerals[0]) * -1), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])

        else:# if variable is posititive
            variables.append(random.choice(choices))
            x = sp.symbols(variables[0])
            if sym_2 == '*': # var first
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} * {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) / int(numerals[0])
          
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), sym_1)
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} * {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) / int(numerals[0])
             
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
            elif sym_2 == '/':
           
                if random.randint(1,2) == 1:
                    equation = fr'{variables[0]} / {numerals[0]} {sym_1} {numerals[1]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) * int(numerals[0])
                
                    #if ending value is not 0, the ncall on the decimal numberline
                    receivant = Whole_Inequality_Graph_Template(float(numerals[1]), sym_1)
                    answerset.append(receivant[0])
                    another.append(receivant[1])
                else:
                    equation = fr'{numerals[1]} {sym_1} {variables[0]} / {numerals[0]}'
                    problemsets.append(sp.latex(sp.sympify(equation),fold_short_frac=False, mode="inline"))
                    numerals[1] = int(numerals[1]) * int(numerals[0])
               
                    #if ending value is not 0, the ncall on the decimal numberline
                    if str(numerals[1])[-1] == "0":
                        receivant = Whole_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])
                    else: 
                        receivant = Decimal_Inequality_Graph_Template(float(numerals[1]), else_situation(sym_1))
                        answerset.append(receivant[0])
                        another.append(receivant[1])

    return(problemsets[0], answerset[0], another[0])

    
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Multiplication_Division("easy", 'latex')
    print(a, r'\\', '\n',b,r'\\', '\n',c)
    print(r'\\')
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Multiplication_Division("medium", 'latex')
    print(a, r'\\', '\n',b,r'\\', '\n',c)
    print(r'\\')
for i in range(3):
    a,b,c = Solving_One_Step_Inequalities_Multiplication_Division("hard", 'latex')
    print(a, r'\\', '\n',b,r'\\', '\n',c)
    print(r'\\')
# Out:
# $- 5 t \geq -5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (3.0,0);\draw[red, fill=red, very thick] (3.0,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 s > 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.5, 0) -- (7,0);\draw[red, fill=white, thick] (2.5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 s < -5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.3333333333333333,0);\draw[red, fill=white, thick] (1.3333333333333333,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 \leq - \frac{u}{2}$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.0,0);\draw[red, fill=red, very thick] (1.0,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 \leq - \frac{p}{2}$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.0,0);\draw[red, fill=red, very thick] (1.0,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 > \frac{b}{5}$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (3.0,0);\draw[red, fill=white, thick] (3.0,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $- 3 z \leq 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (3.0,0) -- (7,0);\draw[red, fill=red, very thick] (3.0,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $- \frac{s}{3} > 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (4,0);\draw[red, fill=white, thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 > - 5 u$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.6, 0) -- (7,0);\draw[red, fill=white, thick] (1.6,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\

# %%
#(smaller graph)
b \geq -2.5
 \begin{tikzpicture}[line width=1pt,line cap=round,x=.8cm,y=1cm]\clip (0,-0.8) rectangle (7,1);
 \draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}
 \draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7+ 1*\x\relax$};
 \draw[->,very thick,red,-latex] (\x + --7 + -2.5,0) -- (12,0);
 \draw[red, fill=red, very thick] (\x + --7 + -2.5,0) circle (-2pt);
 \end{tikzpicture}

# %% [markdown]
# ## Solving Two-Step Inequalities
#
# > Indented block
#
#
# ### Instruction : Solve each inequality and graph its solution.
#
# Learning Targets Should be :
#
# EASY is $60 > 5x + 2$ or $\frac{x}{2} + 2 = 5$
#
# MEDIUM IS $\frac{b + 2}{5} = 5$
#
# HARD IS $\frac{b + 2}{5} = 5$ || $60 > 5x + 2$ || $\frac{x}{2} + 2 = 5$
# (mixture of everything previously + higher number threshhold (up to 30))

# %%
import fractions
import sympy
import random
from fractions import Fraction

def Whole_Inequality_Graph_Template(line_length, symbol):
    line_length = int(line_length)

    number_line_size = -7 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 4 #plus minus 4
    while (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 7) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 3
        elif (number_line_size + 7) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 3

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (14,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    out.append(r'\foreach \x in {1,2,...,13}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')
    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (14,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (14,0);')
    copy.append(r'\foreach \x in {1,2,...,13}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    #out.append(fr'{$\scriptstyle \the\numexpr-{number_line_size}+1*\x\relax$};)')-7 + 1*
    #out.append(r"{}{}{}".format('{$\scriptstyle \the\numexpr-', str(number_line_size), '+1*\x\relax$};)'))
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (12,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (12,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (2,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))


def Decimal_Inequality_Graph_Template(line_length, symbol):
    line_length = float(line_length)
    number_line_size = -2 # "the zero" starting place
    MINIMUM_NUMBERLINE_SIZE = 1 #plus minus 4
    while (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length or (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
        if (number_line_size + 2) + MINIMUM_NUMBERLINE_SIZE < line_length:
            number_line_size = number_line_size + 1
        elif (number_line_size + 2) - MINIMUM_NUMBERLINE_SIZE > line_length:
            number_line_size = number_line_size - 1

    deviation = 0
    number_line_domain = 0
    copy = []
    out = []
    out = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    out.append(r'\clip (0,-0.8) rectangle (7,1);')
    out.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    out.append(r'\foreach \x in {1,2,...,6}')
    out.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    out.append(r'{')
    out.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    out.append(r'};')

    copy = [r'\begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]']
    copy.append(r'\clip (0,-0.8) rectangle (7,1);')
    copy.append(r'\draw  [<->,thick]    (0,0) -- (7,0);')
    copy.append(r'\foreach \x in {1,2,...,6}')
    copy.append(r'\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]')
    copy.append(r'{')
    copy.append(fr'$\scriptstyle \the\numexpr{number_line_size} + 1*\x\relax$')
    copy.append(r'};')
    if symbol == '>':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length}, 0) -- (7,0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=white, thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '>=':
        out.append(fr'\draw[->,very thick,red,-latex] ({(-1 * number_line_size) + line_length},0) -- (7,0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    elif symbol == '<=':
        out.append(fr'\draw[<-,very thick,red,latex-] (0,0) -- ({(-1 * number_line_size) + line_length},0);')
        out.append(fr'\draw[red, fill=red, very thick] ({(-1 * number_line_size) + line_length},0) circle (-2pt);')
        
    out.append(r'\end{tikzpicture}')
    copy.append(r'\end{tikzpicture}')
    return(''.join(out), ''.join(copy))

def else_situation(sym_1):    
    if sym_1 == '<':
        sym_1 = '>'
        return(sym_1)
    elif sym_1 == '>':
        sym_1 = '<'
        return(sym_1)
    elif sym_1 == '>=':
        sym_1 = '<='
        return(sym_1)
    elif sym_1 == '<=':
        sym_1 = '>='
        return(sym_1)

def hard_diff():
    first = ""
    second = ""
    if random.randint(1,2) == 1:
        checker = ""
        variable = random.choice(['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v'])

        number_one = random.randint(1,30)
        number_two = random.randint(1,30)
        number_three = random.randint(1,30)

        sym_1 = random.choice(["+","-"])
        negative = ["", "-"]
        inequality_sign = random.choice([">", "<", ">=", "<="])
        x = sympy.Symbol(str(variable))

        problem = ""
        answer = ""
#problem = fr"({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} {str(inequality_sign)} {str(number_two)}"
            
        if random.randint(1,2) == 1: # division
            if random.randint(1,2) == 1:
                problem = fr"{str(variable)} / {str(number_three)} {str(sym_1)} {str(number_one)} {str(inequality_sign)} {str(number_two)}"
            else:
                problem = fr"{str(number_two)} {str(inequality_sign)} {str(variable)} / {str(number_three)} {str(sym_1)} {str(number_one)}"
            #print("problem", problem)
            answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)
        else: # multiplication
            if random.randint(1,2) == 1:
                problem = fr"{str(random.choice(negative))} {str(number_one)} * {str(variable)} {str(sym_1)} {str(number_three)} {str(inequality_sign)} {str(number_two)}"
            else:
                problem = fr"{str(number_two)} {str(inequality_sign)} {str(random.choice(negative))} {str(number_one)} * {str(variable)} {str(sym_1)} {str(number_three)}"
            #print("problem", problem)
            answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)

        answer = str(answer)
        if str(answer).find("oo") <= 10:
            #print(answer[str(answer).find("&") + 3:-1]) #print(answer[str(answer).find("&") + 3:-1])
            checker = answer[str(answer).find("&") + 3:-1]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])     
        else:
            #print("else")
            #print("HERERE--------------------")
            #print(answer[1:str(answer).find("&") - 2])
            checker = answer[1:str(answer).find("&") - 2]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])
            else:
                if str(float(Fraction(checker[0])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[0]), else_situation(checker[1]))
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[0])), else_situation(checker[1]))
        #print(problem, answer)
        if random.randint(1,2) == 1:
            return(sympy.latex(sympy.sympify(problem,evaluate=False),fold_short_frac=False, mode="inline"), first, second)
        else:
            return(sympy.latex(sympy.sympify(problem),fold_short_frac=False, mode="inline"), first, second)
    else:
        checker = ""
        variable = random.choice(['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v'])

        number_one = random.randint(1,30)
        number_two = random.randint(1,30)
        number_three = random.randint(1,30)

        sym_1 = random.choice(["+","-"])
        negative = ["", "-"]
        inequality_sign = random.choice([">", "<", ">=", "<="])
        x = sympy.Symbol(str(variable))

        problem = ""
        answer = ""
        if random.randint(1,2) == 1:
            problem = fr"{str(random.choice(negative))} ({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} {str(inequality_sign)} {str(number_two)}"
        else:
            problem = fr"{str(number_two)} {str(inequality_sign)} {str(random.choice(negative))} ({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} "
        answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)

        answer = str(answer)
        if str(answer).find("oo") <= 10:
            #print(answer[str(answer).find("&") + 3:-1]) #print(answer[str(answer).find("&") + 3:-1])
            checker = answer[str(answer).find("&") + 3:-1]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])     
        else:
            #print("else")
            #print("HERERE--------------------")
            #print(answer[1:str(answer).find("&") - 2])
            checker = answer[1:str(answer).find("&") - 2]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])
            else:
                if str(float(Fraction(checker[0])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[0]), else_situation(checker[1]))
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[0])), else_situation(checker[1]))
        #print(problem, answer)
        return(sympy.latex(sympy.sympify(problem, evaluate=False),fold_short_frac=False, mode="inline"), first, second)


def Solving_Two_Step_Inequalities(option_difficulty = 'easy', expr = 'latex'):
    first = ""
    second = ""
    if option_difficulty == "easy": 
        checker = ""
        variable = random.choice(['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v'])

        number_one = random.randint(1,10)
        number_two = random.randint(1,10)
        number_three = random.randint(1,10)

        sym_1 = random.choice(["+","-"])
        negative = ["", "-"]
        inequality_sign = random.choice([">", "<", ">=", "<="])
        x = sympy.Symbol(str(variable))

        problem = ""
        answer = ""
#problem = fr"({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} {str(inequality_sign)} {str(number_two)}"
            
        if random.randint(1,2) == 1: # division
            if random.randint(1,2) == 1:
                problem = fr"{str(variable)} / {str(number_three)} {str(sym_1)} {str(number_one)} {str(inequality_sign)} {str(number_two)}"
            else:
                problem = fr"{str(number_two)} {str(inequality_sign)} {str(variable)} / {str(number_three)} {str(sym_1)} {str(number_one)}"
            #print("problem", problem)
            answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)
        else: # multiplication
            if random.randint(1,2) == 1:
                problem = fr"{str(random.choice(negative))} {str(number_one)} * {str(variable)} {str(sym_1)} {str(number_three)} {str(inequality_sign)} {str(number_two)}"
            else:
                problem = fr"{str(number_two)} {str(inequality_sign)} {str(random.choice(negative))} {str(number_one)} * {str(variable)} {str(sym_1)} {str(number_three)}"
            #print("problem", problem)
            answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)

        answer = str(answer)
        if str(answer).find("oo") <= 10:
            #print(answer[str(answer).find("&") + 3:-1]) #print(answer[str(answer).find("&") + 3:-1])
            checker = answer[str(answer).find("&") + 3:-1]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])     
        else:
            #print("else")
            #print("HERERE--------------------")
            #print(answer[1:str(answer).find("&") - 2])
            checker = answer[1:str(answer).find("&") - 2]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])
            else:
                if str(float(Fraction(checker[0])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[0]), else_situation(checker[1]))
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[0])), else_situation(checker[1]))
        #print(problem, answer)
        if random.randint(1,2) == 1:
            return(sympy.latex(sympy.sympify(problem,evaluate=False),fold_short_frac=False, mode="inline"), first, second)
        else:
            return(sympy.latex(sympy.sympify(problem),fold_short_frac=False, mode="inline"), first, second)
  
    elif option_difficulty == "medium":
        checker = ""
        variable = random.choice(['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v'])

        number_one = random.randint(1,10)
        number_two = random.randint(1,10)
        number_three = random.randint(1,10)

        sym_1 = random.choice(["+","-"])
        negative = ["", "-"]
        inequality_sign = random.choice([">", "<", ">=", "<="])
        x = sympy.Symbol(str(variable))

        problem = ""
        answer = ""
        if random.randint(1,2) == 1:
            problem = fr"{str(random.choice(negative))} ({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} {str(inequality_sign)} {str(number_two)}"
        else:
            problem = fr"{str(number_two)} {str(inequality_sign)} {str(random.choice(negative))} ({str(variable)} {str(sym_1)} {str(number_one)}) / {str(number_three)} "
        answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)

        answer = str(answer)
        if str(answer).find("oo") <= 10:
            #print(answer[str(answer).find("&") + 3:-1]) #print(answer[str(answer).find("&") + 3:-1])
            checker = answer[str(answer).find("&") + 3:-1]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])     
        else:
            #print("else")
            #print("HERERE--------------------")
            #print(answer[1:str(answer).find("&") - 2])
            checker = answer[1:str(answer).find("&") - 2]
            #print(checker, "checker")
            list(checker)
            checker = checker.split()
            #print(checker)
            if str(checker[0]) == str(variable):
                #print("noraml")
                #print(checker[2:3], "inequal")
                #print(checker[3:], "numba")
                #print(float(Fraction(checker[3:])))
                if str(float(Fraction(checker[2])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[2]), checker[1])
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[2])), checker[1])
            else:
                if str(float(Fraction(checker[0])))[-2:] == ".0":
                    first, second = Whole_Inequality_Graph_Template(float(checker[0]), else_situation(checker[1]))
                else:
                    first, second = Decimal_Inequality_Graph_Template(float(Fraction(checker[0])), else_situation(checker[1]))
        #print(problem, answer)
        return(sympy.latex(sympy.sympify(problem, evaluate=False),fold_short_frac=False, mode="inline"), first, second)
    elif option_difficulty == "hard":
        return(hard_diff())

    
for i in range(10000000):
    a,b,c = Solving_Two_Step_Inequalities("easy", 'latex')
    print(a, r'\\', '\n', b, r'\\', '\n', c)
    print(r'\\')
for i in range(5):
    a,b,c = Solving_Two_Step_Inequalities("medium", 'latex')
    print(a, r'\\', '\n',b,r'\\', '\n',c)
    print(r'\\')
for i in range(5):
    a,b,c = Solving_Two_Step_Inequalities("hard", 'latex')
    print(a, r'\\', '\n',b,r'\\', '\n',c)
    print(r'\\')
# Out:
# $1 \geq - 7 t - 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.4285714285714286,0) -- (7,0);\draw[red, fill=red, very thick] (1.4285714285714286,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 \geq \frac{v}{8} + 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $7 > - 4 b - 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.5, 0) -- (7,0);\draw[red, fill=white, thick] (1.5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 \geq \frac{b}{10} - 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr59 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (11,0);\draw[red, fill=red, very thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr59 + 1*\x\relax$};\end{tikzpicture}
# \\
# $7 < 9 r + 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.2222222222222223, 0) -- (7,0);\draw[red, fill=white, thick] (2.2222222222222223,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{d}{3} + 2 < 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 \leq 2 z + 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (11,0) -- (12,0);\draw[red, fill=red, very thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $10 k - 7 < 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.8,0);\draw[red, fill=white, thick] (2.8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{z}{6} - 4 \geq 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10,0) -- (12,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 < 3 - 5 r$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.8,0);\draw[red, fill=white, thick] (1.8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 k - 5 \leq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $k \left(-7\right) - 5 \geq 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.4285714285714286,0);\draw[red, fill=red, very thick] (1.4285714285714286,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{k}{4} - 6 \geq 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr35 + 1*\x\relax$};\draw[->,very thick,red,-latex] (9,0) -- (12,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr35 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 r + 3 > 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.4, 0) -- (7,0);\draw[red, fill=white, thick] (2.4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 \leq \frac{a}{10} + 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-55 + 1*\x\relax$};\draw[->,very thick,red,-latex] (5,0) -- (12,0);\draw[red, fill=red, very thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-55 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{x}{7} + 7 \leq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (7,0);\draw[red, fill=red, very thick] (7,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 \geq 3 h - 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 b - 3 \leq 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.625,0);\draw[red, fill=red, very thick] (2.625,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 \geq \frac{s}{10} - 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr50 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr50 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 - v < 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10, 0) -- (12,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 \geq \frac{k}{6} - 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 \geq - 5 h - 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.4,0) -- (7,0);\draw[red, fill=red, very thick] (1.4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 > 4 v - 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{t}{10} - 9 \geq 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr110 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10,0) -- (12,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr110 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 h - 2 < 4$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.5,0);\draw[red, fill=white, thick] (2.5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 z - 1 < 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.4,0);\draw[red, fill=white, thick] (2.4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{y}{5} - 5 < 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr20 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr20 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 \leq \frac{v}{9} + 4$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-13 + 1*\x\relax$};\draw[->,very thick,red,-latex] (4,0) -- (12,0);\draw[red, fill=red, very thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-13 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 > 2 q + 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (5,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{k}{8} + 7 \leq 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-19 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (3,0);\draw[red, fill=red, very thick] (3,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-19 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 - s > 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (11,0);\draw[red, fill=white, thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $v \left(-3\right) - 2 < 4$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (5, 0) -- (12,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 + t \left(-5\right) \leq 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.8,0) -- (7,0);\draw[red, fill=red, very thick] (1.8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{r}{1} - 8 < 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 > - 4 r - 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.75, 0) -- (7,0);\draw[red, fill=white, thick] (1.75,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{h}{10} + 10 \geq 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-85 + 1*\x\relax$};\draw[->,very thick,red,-latex] (5,0) -- (12,0);\draw[red, fill=red, very thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-85 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{d}{8} + 10 \leq 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-76 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (4,0);\draw[red, fill=red, very thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-76 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 t + 9 < 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (6,0);\draw[red, fill=white, thick] (6,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $b \left(-3\right) - 8 \leq 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.3333333333333335,0) -- (7,0);\draw[red, fill=red, very thick] (1.3333333333333335,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 \leq \frac{a}{1} - 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10,0) -- (12,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $s + 6 \leq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (8,0);\draw[red, fill=red, very thick] (8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 k - 10 \leq 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr8 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr8 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 \geq \frac{z}{7} - 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr95 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr95 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 + q \left(-6\right) \geq 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.6666666666666667,0);\draw[red, fill=red, very thick] (1.6666666666666667,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $7 > z \left(-5\right) - 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (4, 0) -- (12,0);\draw[red, fill=white, thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 \geq \frac{x}{1} + 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (4,0);\draw[red, fill=red, very thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 \geq 6 x + 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.3333333333333335,0);\draw[red, fill=red, very thick] (2.3333333333333335,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 > b + 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 \geq \frac{u}{5} - 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr41 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr41 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 \leq 1 z + 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (6,0) -- (12,0);\draw[red, fill=red, very thick] (6,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 \geq \frac{k}{7} + 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (7,0);\draw[red, fill=red, very thick] (7,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{x}{7} + 9 \geq 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-10 + 1*\x\relax$};\draw[->,very thick,red,-latex] (3,0) -- (12,0);\draw[red, fill=red, very thick] (3,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-10 + 1*\x\relax$};\end{tikzpicture}
# \\
# $- 2 w - 9 > 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.5,0);\draw[red, fill=white, thick] (1.5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 > - 4 q - 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.25, 0) -- (7,0);\draw[red, fill=white, thick] (1.25,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\end{tikzpicture}
# \\
# $10 > \frac{z}{8} - 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr77 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (11,0);\draw[red, fill=white, thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr77 + 1*\x\relax$};\end{tikzpicture}
# \\
# $7 \geq \frac{d}{4} - 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr53 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (11,0);\draw[red, fill=red, very thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr53 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{s}{3} + 10 \leq 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (7,0);\draw[red, fill=red, very thick] (7,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $10 < - 4 d - 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-6 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.25,0);\draw[red, fill=white, thick] (1.25,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-6 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{x}{9} + 4 < 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{x}{10} + 7 > 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-55 + 1*\x\relax$};\draw[->,very thick,red,-latex] (5, 0) -- (12,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-55 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 p - 6 \leq 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (2.4,0);\draw[red, fill=red, very thick] (2.4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $- 5 t - 1 \geq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.4,0);\draw[red, fill=red, very thick] (1.4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-3 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 < z - 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10, 0) -- (12,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr5 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 > \frac{d}{2} - 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr20 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr20 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 - 8 w < 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.875, 0) -- (7,0);\draw[red, fill=white, thick] (2.875,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{t}{6} - 6 > 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10, 0) -- (12,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 \geq \frac{k}{3} + 2$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr8 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (10,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr8 + 1*\x\relax$};\end{tikzpicture}
# \\
# $1 \leq \frac{b}{9} - 8$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr71 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10,0) -- (12,0);\draw[red, fill=red, very thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr71 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 r + 7 < 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (7,0);\draw[red, fill=white, thick] (7,0) circle (-2pt);\end{tikzpicture} \\
# ...
# \\
# $1 > k - 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=white, thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 w + 3 \geq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (9,0) -- (12,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $5 < 5 w + 9$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[->,very thick,red,-latex] (1.2, 0) -- (7,0);\draw[red, fill=white, thick] (1.2,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 k - 1 \geq 7$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\draw[->,very thick,red,-latex] (2.333333333333333,0) -- (7,0);\draw[red, fill=red, very thick] (2.333333333333333,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-1 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 < \frac{h}{2} + 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (11, 0) -- (12,0);\draw[red, fill=white, thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $2 \geq 8 q - 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (8,0);\draw[red, fill=red, very thick] (8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 \geq \frac{u}{2} - 6$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr17 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (11,0);\draw[red, fill=red, very thick] (11,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr17 + 1*\x\relax$};\end{tikzpicture}
# \\
# $s \left(-9\right) - 3 \geq 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.5555555555555556,0);\draw[red, fill=red, very thick] (1.5555555555555556,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 \leq 3 + v \left(-4\right)$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (0,0) -- (1.25,0);\draw[red, fill=red, very thick] (1.25,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=1cm,y=.5cm]\clip (0,-0.8) rectangle (7,1);\draw  [<->,thick]    (0,0) -- (7,0);\foreach \x in {1,2,...,6}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-2 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{a}{5} + 7 < 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-25 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (5,0);\draw[red, fill=white, thick] (5,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-25 + 1*\x\relax$};\end{tikzpicture}
# \\
# $6 \geq z + 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (9,0);\draw[red, fill=red, very thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-4 + 1*\x\relax$};\end{tikzpicture}
# \\
# $3 \leq - h - 3$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-10 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (4,0);\draw[red, fill=red, very thick] (4,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-10 + 1*\x\relax$};\end{tikzpicture}
# \\
# $4 - 3 u < 1$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (8, 0) -- (12,0);\draw[red, fill=white, thick] (8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $\frac{q}{2} + 10 \geq 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (7,0) -- (12,0);\draw[red, fill=red, very thick] (7,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 < \frac{k}{10} - 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr131 + 1*\x\relax$};\draw[->,very thick,red,-latex] (9, 0) -- (12,0);\draw[red, fill=white, thick] (9,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr131 + 1*\x\relax$};\end{tikzpicture}
# \\
# $9 > \frac{b}{1} + 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[<-,very thick,red,latex-] (2,0) -- (6,0);\draw[red, fill=white, thick] (6,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 p - 3 > 5$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\draw[->,very thick,red,-latex] (8, 0) -- (12,0);\draw[red, fill=white, thick] (8,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr-7 + 1*\x\relax$};\end{tikzpicture}
# \\
# $8 < \frac{a}{3} - 10$ \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\draw[->,very thick,red,-latex] (10, 0) -- (12,0);\draw[red, fill=white, thick] (10,0) circle (-2pt);\end{tikzpicture} \\
#  \begin{tikzpicture}[line width=1pt,line cap=round,x=.5cm,y=.5cm]\clip (0,-0.8) rectangle (14,1);\draw  [<->,thick]    (0,0) -- (14,0);\foreach \x in {1,2,...,13}\draw (\x,-2pt) -- (\x,2pt) node [anchor=north,below=3pt]{$\scriptstyle \the\numexpr44 + 1*\x\relax$};\end{tikzpicture}
# \\
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5c0809223d74> in <module>()
#     417
#     418 for i in range(10000000):
# --> 419     a,b,c = Solving_Two_Step_Inequalities("easy", 'latex')
#     420     print(a, r'\\', '\n', b, r'\\', '\n', c)
#     421     print(r'\\')
#
# <ipython-input-1-5c0809223d74> in Solving_Two_Step_Inequalities(option_difficulty, expr)
#     301                 problem = fr"{str(number_two)} {str(inequality_sign)} {str(random.choice(negative))} {str(number_one)} * {str(variable)} {str(sym_1)} {str(number_three)}"
#     302             #print("problem", problem)
# --> 303             answer = sympy.solvers.inequalities.reduce_rational_inequalities([[sympy.sympify(problem)]], x)
#     304
#     305         answer = str(answer)
#
# /usr/local/lib/python3.7/dist-packages/sympy/core/sympify.py in sympify(a, locals, convert_xor, strict, rational, evaluate)
#     478     try:
#     479         a = a.replace('\n', '')
# --> 480         expr = parse_expr(a, local_dict=locals, transformations=transformations, evaluate=evaluate)
#     481     except (TokenError, SyntaxError) as exc:
#     482         raise SympifyError('could not parse %r' % a, exc)
#
# /usr/local/lib/python3.7/dist-packages/sympy/parsing/sympy_parser.py in parse_expr(s, local_dict, transformations, global_dict, evaluate)
#     997                     expected a function in `transformations`,
#     998                     not %s''' % func_name(_)))
# --> 999             if arity(_) != 3:
#    1000                 raise TypeError(filldedent('''
#    1001                     a transformation should be function that
#
# /usr/local/lib/python3.7/dist-packages/sympy/core/function.py in arity(cls)
#     138     eval_ = getattr(cls, 'eval', cls)
#     139
# --> 140     parameters = inspect.signature(eval_).parameters.items()
#     141     if [p for _, p in parameters if p.kind == p.VAR_POSITIONAL]:
#     142         return
#
# /usr/lib/python3.7/inspect.py in signature(obj, follow_wrapped)
#    3081 def signature(obj, *, follow_wrapped=True):
#    3082     """Get a signature object for the passed callable."""
# -> 3083     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3084
#    3085
#
# /usr/lib/python3.7/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2831         """Constructs Signature for the given callable object."""
#    2832         return _signature_from_callable(obj, sigcls=cls,
# -> 2833                                         follow_wrapper_chains=follow_wrapped)
#    2834
#    2835     @property
#
# /usr/lib/python3.7/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2282         # If it's a pure Python function, or an object that is duck type
#    2283         # of a Python function (Cython functions, for instance), then:
# -> 2284         return _signature_from_function(sigcls, obj)
#    2285
#    2286     if _signature_is_builtin(obj):
#
# /usr/lib/python3.7/inspect.py in _signature_from_function(cls, func)
#    2134     arg_names = func_code.co_varnames
#    2135     positional = tuple(arg_names[:pos_count])
# -> 2136     keyword_only_count = func_code.co_kwonlyargcount
#    2137     keyword_only = arg_names[pos_count:(pos_count + keyword_only_count)]
#    2138     annotations = func.__annotations__
#
# KeyboardInterrupt:

# %% [markdown]
# ## Solving Multi-Step Inequalities  (RN it has issues with variables canceling out. For ex: $ -5a + 5a $)
# ### Instruction : Solve each inequality and graph its solution.
#
# Learning Targets Should be :
#
# EASY is $-11 > 6 - 2n -6$ or $0 > 2b + 4b$
#
# MEDIUM IS $5k - 2k > -9$ or $23 - 2a > -4(5+2a)$
#
# HARD IS $ -5(2b+7) + b < 2b + 11$ or $5(5t + 2) < 8(2t + 2)$
