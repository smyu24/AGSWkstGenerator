# %% [markdown]
# # Part 8 Proportions and Percents

# %% [markdown]
# ## Fractions, Decimals, and Percents
# ### section 1
# #### instruction : Write each as a decimal. Round to the thousandths place.
#
# -  easy
#   - case 1
#   - 1-200
#   - problem : $ 172 \% $
#   - answer : $ 1.72 $
#
# -  medium
#   - case 1
#   - 1.01-200.99
#   - problem : $ 172.98 \% $
#   - answer : $ 1.7298 $
#
# -  hard
#   - case 1
#   - 0.0001-999.9999
#   - problem : $ 0.098 \% $
#   - answer : $ 0.0098 $
#
# ### section 2
# #### instruction : Write each as a percent. Round to the nearest tenth of a percent.
#
# -  easy
#   - case 1
#   - 0.01-1.00
#   - problem : $ 0.08 $
#   - answer : $8 \% $
#
# -  medium
#   - case 1
#   - 0.001-99.999
#   - problem : $ 98.172 $
#   - answer : $ 9817.2 \% $
#
# -  hard
#   - case 1
#   - 0.00001-999.9999
#   - problem : $ 0.00123 $
#   - answer : $ 0.123 \% $
#
# ### section 3
# #### instruction : Write each as a fraction.
#
# -  easy
#   - case 1
#   - 1-100
#   - problem : $ 7 \% $
#   - answer : $ \frac{7}{100} $
#
# -  medium
#   - case 1
#   - 0.01-99.99
#   - problem : $ 98.17 \% $
#   - answer : $ \frac{9817}{10000} $
#
# -  hard
#   - case 1
#   - 0.01-99.99
#   - problem : $ 19.\overline{9} \% $
#   - answer : $  \% $
#
# ### section 4
# #### instruction : Write each as a percent. Use repeating decimals when necessary.
#
#
# -  easy
#   - case 1
#   - 1/ 1-100
#   - problem : $ \frac{1}{20} $
#   - answer : $ 5 \% $
#
# -  medium
#   - case 1
#   - 1-50 / 1-100
#   - problem : $ \frac{10}{100} $
#   - answer : $ 10 \% $
#
# -  hard
#   - case 1
#   - 1-100 / 1-100
#   - problem : $ \frac{87}{13} $
#   - answer : $ 669.230769231 \% $

# %%
#First Section

import math
import random


def Percents_Fractions_Decimal_Conversion_1(option_difficulty, option_random):
    problemsets = []
    answerset = []
    temp = 0
    list_temp = []

    if(option_difficulty == "easy"):
        problemsets.append("0." + str(random.randint(1, 99)))
    
    elif(option_difficulty == "medium"):
        problemsets.append(str(random.randint(1, 99)) + "." + str(random.randint(1, 99)))

    elif(option_difficulty == "hard"):
        problemsets.append(str(random.randint(-999, 999)) + "." + str(random.randint(1, 999)))


    temp = round(float(str(problemsets[0])) * 100, 2)
    list_temp = list(str(temp))
    if int(list_temp[-1]) == 0:
        temp = int(temp)
    answerset.append(str(temp) + "%")


    return(answerset[0], problemsets[0])


a,b = Percents_Fractions_Decimal_Conversion_1("hard", False)
print(a,b)
# Out:
# 24951.7% 249.517

# %%
#Second Section

import math
import random


def Percents_Fractions_Decimal_Conversion_2(option_difficulty, option_random):
    problemsets = []
    answerset = []
    temp = 0
    list_temp = []

    if(option_difficulty == "easy"):
        problemsets.append("0." + str(random.randint(1, 99)))
    
    elif(option_difficulty == "medium"):
        problemsets.append(str(random.randint(1, 20)) + "." + str(random.randint(1, 99)))

    elif(option_difficulty == "hard"):
        problemsets.append(str(random.randint(1, 999)) + "." + str(random.randint(1, 999)))


    temp = round(float(str(problemsets[0])) * 100, 2)
    list_temp = list(str(temp))
    if int(list_temp[-1]) == 0:
        temp = int(temp)
    answerset.append(str(temp) + "%")


    return(problemsets[0], answerset[0])


a,b = Percents_Fractions_Decimal_Conversion_2("hard", False)
print(a,b)
# Out:
# 767.873 76787.3%

# %%
#Third Section NEED ALTERNATE TO FRACTION

import fractions
import math
import random
from fractions import Fraction

def Percents_Fractions_Decimal_Conversion_3(option_difficulty, option_random):
    problemsets_1 = []
    problemsets_2 = []
    answerset = []
    temp = 0
    list_temp = []
    percent = 0
    replace = ""
    holder = 0

    if(option_difficulty == "easy"):
        problemsets_2.append("0." + str(random.randint(1, 99)))
    
    elif(option_difficulty == "medium"):
        problemsets_2.append("0." + str(random.randint(1, 999)))

    elif(option_difficulty == "hard"):
        problemsets_2.append("0." + str(random.randint(1, 9999)))
    
    temp = round(float(str(problemsets_2[0])) * 100, 2)
    
    list_temp = list(str(temp))
    if int(list_temp[-1]) == 0:
        temp = int(temp)
    problemsets_1.append(str(temp) + "%")
    
    percent = Fraction(problemsets_2[0])
    percent = str(percent)
    percent.replace("Fraction(",'')
    percent.replace(")",'')

    
    answerset.append(percent)

    return(problemsets_1[0], answerset[0])


a,b = Percents_Fractions_Decimal_Conversion_3("hard", False)
print(a,b)
# Out:
# 63.5% 127/200

# %%
#Fourth Section

import fractions
import math
import random
from fractions import Fraction

def Percents_Fractions_Decimal_Conversion_4(option_difficulty, option_random):
    problemsets_1 = []
    problemsets_2 = []
    answerset = []
    temp = 0
    list_temp = []
    percent = 0
    replace = ""
    holder = 0

    if(option_difficulty == "easy"):
        problemsets_2.append("0." + str(random.randint(1, 99)))
    
    elif(option_difficulty == "medium"):
        problemsets_2.append("0." + str(random.randint(1, 999)))

    elif(option_difficulty == "hard"):
        problemsets_2.append("0." + str(random.randint(1, 9999)))
    
    temp = round(float(str(problemsets_2[0])) * 100, 2)
    
    list_temp = list(str(temp))
    if int(list_temp[-1]) == 0:
        temp = int(temp)
    problemsets_1.append(str(temp) + "%")
    
    percent = Fraction(problemsets_2[0])
    percent = str(percent)
    percent.replace("Fraction(",'')
    percent.replace(")",'')

    
    answerset.append(percent)

    return(answerset[0], problemsets_1[0])


a,b = Percents_Fractions_Decimal_Conversion_4("easy", False)
print(a,b)
# Out:
# here 91/100 ['0.91']
# 91/100 91%

# %% [markdown]
# ## Percent Word Problems
# ### section 1
# #### instruction : Solve each problem. (Round answers to hundreds place)
#
# - Option : E/M/H
#
# -----
#
# - intA = 1~100
#
# - intB = 1-200
#
# - floatA = 1.00 ~ 99.99
#
# - floatB = 100.00 ~ 999.99
#
# ---
#
# -  easy
#   - case 1
#   - What percent of intB is intA?
#   - problem : What percent of $126$ is $22$?
#   - answer : $ 17.5% $
#   - x = ( 22 / 126 ) * 100
#   - case 2
#   - intB is intA % of what?
#   - problem : $81$ is $56 \%$ of what?
#   - answer : $ 144.64 $
#   - x = ( 81 / 56 ) * 100
#   - case 3
#   - intB is what percent of intA?
#   - problem : $46$ is what percent of $107$?
#   - answer : $ 43 \% $
#   - x = (46 / 107 )*100
#   - case 4
#   - intA % of what is intB?
#   - problem : $17\%$ of what is $156$?
#   - answer : $ 917.6 $
#   - x = (156 / 17)*(1/100)
#
# -  medium
#   - case 1
#   - What percent of floatA is intB?
#   - problem : What percent of $81.88$ is $122$?
#   - answer : $ 149.00 \% $
#   - x = (122 / 81.88) * 100
#
#   - case 2
#   - floatB is intA % of what?
#   - problem : $144.26$ is $23 \%$ of what?
#   - answer : $ 627.21 $
#   - x = ( 144.26 / 23 ) * 100
#
#   - case 3
#   - floatB is what percent of intA?
#   - problem : $199.88$ is what percent of $80 $?
#   - answer : $ 40.02 \% $
#   - x = (80 / 199.88 )*100
#   - case 4
#   - intA % of what is floatB?
#   - problem : $76\%$ of what is $188.12$?
#   - answer : $ 247.53 $
#   - x = (188.12 / 76)*(1/100)
#
# - hard
#   - case 1
#   - What percent of floatA is floatB?
#   - problem : What percent of $81.88$ is $132.66$?
#   - answer : $ 162.02 \% $
#   - x = (132.66 / 81.88) * 100
#
#   - case 2
#   - floatB is floatA % of what?
#   - problem : $144.26$ is $17.12 \%$ of what?
#   - answer : $ 842.64 $
#   - x = ( 144.26 / 17.12 ) * 100
#
#   - case 3
#   - floatB is what percent of floatA?
#   - problem : $199.88$ is what percent of $122.12$?
#   - answer : $ 61.10 \% $
#   - x = (122.12 / 199.88 )*100
#
#   - case 4
#   - floatA % of what is floatB?
#   - problem : $12.23\%$ of what is $188.12$?
#   - answer : $ 1538.18 $
#   - x = (188.12 / 12.23)*(1/100)

# %%
# Out:
#   File "<ipython-input-1-65053c33c875>", line 1
#     pip show sympy
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Finding Percent Change
# ### section 1
# #### instruction : Find each percent change. Round to the nearest tenth of a percent. State if it is an increase or decrease. (round to nearest hundredth if needed)
#
# -----
#
# - intA = 1~100
#
# - intB = 1-200
#
# - floatA = 0.1 ~ 99.9
#
# - floatB = 0.1 ~ 199.9
#
# - unit = [ 'hours' , 'seconds', 'km' , 'minutes' , 'ft' , 'grams', 'm' ,'lb']
#
# ---
#
# -  easy
#   - case 1
#   - From intA to intB
#   - problem : From $82 $ to $38$
#   - x = ( intB - intA ) / intA
#   - answer : $53.7 \% $ decrease
#
#
# -  medium
#   - case 1
#   - From intA to floatB
#   - problem : From $55 $ to $103.2$
#   - answer : What percent of 30 is 60
#   - case 2
#   - From floatB to intB
#   - problem : From $92.2 $ to $122$
#   - answer : 30 is what percent of 60
#
# -   hard
#   - case 1
#   - From floatA to floatB
#   - problem : From $55.5 $ to $103.2$
#   - x = ( floatB - floatA ) / floatA
#   - answer : $ \% $
#   - case 2
#   - From floatB to floatA
#   - problem : From $92.2 $ to $9.7$
#   - x = ( floatA - floatB ) / floatB
#   - answer : $ \% $
# ---
#
# ### section 2
# #### pretty much same thing just add unit
# ---
#
# -  easy
#   - case 1
#   - From intA [unit] to intB [unit]
#   - problem : From $82$km to $38$km
#   - x = ( intB - intA ) / intA
#   - answer : $53.7 \% $ decrease
#   - case 2
#   - From intA[unit] to floatA[unit]
#   - problem : From $92$ lb to $9.7$ lb
#   - x = ( intB - floatA ) / floatA
#   - answer : $89.5 \% $ decrease
#
# -  medium
#   - case 1
#   - From intA[unit] to floatB[unit]
#   - problem : From $55$ grams to $103.2$ grams
#   - x = ( floatB - intA ) / intA
#   - answer : $ \% $
#   - case 2
#   - From floatB[unit] to intB[unit]
#   - problem : From $92.2$ minutes to $122$ minutes
#   - x = ( floatA - intB ) / intB
#   - answer : $ \% $
#
# -   hard
#   - case 1
#   - From floatA[unit] to floatB[unit]
#   - problem : From $55.5 $ to $103.2$
#   - x = ( floatB - floatA ) / floatA
#   - answer : $ \% $
#   - case 2
#   - From floatB[unit] to floatA[unit]
#   - problem : From $92.2 $ hours to $9.7$ hours
#   - x = ( floatA - floatB ) / floatB
#   - answer : $ \% $
# ---

# %%
import random
import sympy

def percentify(num):
    if str(float(num))[-2:] == ".0":
        num = int(num)
    return(str(num) + "%")

def inc_dec_formatter(num, choice):
    num = str(num)
    if choice == True:
        return(num + " Increase")
    elif choice == False:
        return(num + " Decrease")

measurements = ["miles", "grams", "ft", "minutes", "seconds", "meters", "kilos", "dollars", "liters", "tons"]
pick = [True, False]

def Finding_Percent_Change_Section_1(option_difficulty = 'easy', expr = 'latex'):
    problem = ""
    answer = 0
    type = ""

    intA = random.randint(1,100)
    intB = random.randint(1,200)
    floatA = float(str(random.randint(1,99)) + "." + str(random.randint(1,9)))
    floatB = float(str(random.randint(1,199)) + "." + str(random.randint(1,9)))

    chosen = random.choice(pick)
    if option_difficulty == "easy": #From 82 to 38
        type = False
        problem = "From " + str(intA) + " to " + str(intB) 
        answer = ( intB - intA ) / intA
        if intB >= intA:
            answer = answer + 1
            type = True
        else:
            answer = float(answer) * -1
        return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))


    elif option_difficulty == "medium": #What percent of  81.88  is  122 ? 
        if chosen == True:
            type = False
            problem = "From " + str(intA) + " to " + str(floatB) 
            answer = ( floatB - intA ) / intA
            if floatB >= intA:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
        else:
            type = False
            problem = "From " + str(floatB) + " to " + str(intB) 
            answer = ( intB - floatB ) / floatB
            if intB >= floatB:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))


    elif option_difficulty == "hard": # 76% of what is 188.12 ? || 144.26  is  23%  of what? 
        if chosen == True:
            type = False
            problem = "From " + str(floatA) + " to " + str(floatB) 
            answer = ( floatB - floatA ) / floatA
            if floatB >= floatA:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
        else:
            type = False
            problem = "From " + str(floatB) + " to " + str(floatA) 
            answer = ( floatA - floatB ) / floatB
            if floatA >= floatB:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
    

for i in range(3):
    a,b = Finding_Percent_Change_Section_1("easy", "latex")
    print(a, '\n',b)

for i in range(2):
    a,b = Finding_Percent_Change_Section_1("medium", "latex")
    print(a, '\n',b)

for i in range(2):
    a,b = Finding_Percent_Change_Section_1("hard", "latex")
    print(a,b)
# Out:
# From 6 to 164
#  2733.33% Increase
# From 11 to 17
#  154.55% Increase
# From 8 to 169
#  2112.5% Increase
# From 51.2 to 5
#  90.23% Decrease
# From 57 to 140.4
#  246.32% Increase
# From 51.1 to 68.6 134.25% Increase
# From 14.2 to 76.8 540.85% Increase

# %%
import random
import sympy

def percentify(num):
    if str(float(num))[-2:] == ".0":
        num = int(num)
    return(str(num) + "%")

def inc_dec_formatter(num, choice):
    num = str(num)
    if choice == True:
        return(num + " Increase")
    elif choice == False:
        return(num + " Decrease")

measurements = ["miles", "grams", "ft", "minutes", "seconds", "meters", "kilos", "dollars", "liters", "tons"]
pick = [True, False]

def Finding_Percent_Change_Section_2(option_difficulty = 'easy', expr = 'latex'):
    problem = ""
    answer = 0
    type = ""
    measure = random.choice(measurements)

    intA = random.randint(1,100)
    intB = random.randint(1,200)
    floatA = float(str(random.randint(1,99)) + "." + str(random.randint(1,9)))
    floatB = float(str(random.randint(1,199)) + "." + str(random.randint(1,9)))

    chosen = random.choice(pick)
    if option_difficulty == "easy": #From 82 to 38
        type = False
        problem = "From " + str(intA) + " " + str(measure) + " to " + str(intB) + " " + str(measure)
        answer = ( intB - intA ) / intA
        if intB >= intA:
            answer = answer + 1
            type = True
        else:
            answer = float(answer) * -1
        return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))


    elif option_difficulty == "medium": #What percent of  81.88  is  122 ? 
        if chosen == True:
            type = False
            problem = "From " + str(intA) + " " + str(measure) + " to " + str(floatB) + " " + str(measure)
            answer = ( floatB - intA ) / intA
            if floatB >= intA:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
        else:
            type = False
            problem = "From " + str(floatB) + " " + str(measure) + " to " + str(intB) + " " + str(measure)
            answer = ( intB - floatB ) / floatB
            if intB >= floatB:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))


    elif option_difficulty == "hard": # 76% of what is 188.12 ? || 144.26  is  23%  of what? 
        if chosen == True:
            type = False
            problem = "From " + str(floatA) + " " + str(measure) + " to " + str(floatB) + " " + str(measure)
            answer = ( floatB - floatA ) / floatA
            if floatB >= floatA:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
        else:
            type = False
            problem = "From " + str(floatB) + " " + str(measure) + " to " + str(floatA) + " " + str(measure)
            answer = ( floatA - floatB ) / floatB
            if floatA >= floatB:
                answer = answer + 1
                type = True
            else:
                answer = float(answer) * -1
            return(problem, inc_dec_formatter(percentify(round(100 * round(answer, 4), 2)), type))
    

for i in range(3):
    a,b = Finding_Percent_Change_Section_2("easy", "latex")
    print(a, '\n',b)

for i in range(2):
    a,b = Finding_Percent_Change_Section_2("medium", "latex")
    print(a, '\n',b)

for i in range(2):
    a,b = Finding_Percent_Change_Section_2("hard", "latex")
    print(a,b)
# Out:
# From 17 liters to 20 liters
#  117.65% Increase
# From 52 seconds to 127 seconds
#  244.23% Increase
# From 44 dollars to 178 dollars
#  404.55% Increase
# From 101.9 minutes to 6 minutes
#  94.11% Decrease
# From 25.8 grams to 97 grams
#  375.97% Increase
# From 157.2 meters to 90.8 meters 42.24% Decrease
# From 8.3 liters to 70.5 liters 849.4% Increase

# %% [markdown]
# ## Markup, Discount, and Tax
# ### section 1
# #### instruction : Find the final price of each item. (Round to the nearest hundredth if needed)
#
# -----
#
# - intA = 1~100
#
# - intB = 1-100
#
# - floatA = 10.01 ~ 99.99
#
# - floatB = 1000.01 ~ 1999.99
#
# - cheap_items = [ 'a DVD' , 'a comic book', 'an oil change' , 'a computer' , 'a macbook' , 'a pen', 'concert tickets' ,'a telescope','a book','a camera','a sled','an airpod', '']
#
# - expensive_items = [ 'a computer' , 'a macbook' ,'a telescope','a camera','a snow board']
#
# - action_up = ['Mark up', 'Tax']
# - action_down = ['Sale', 'Discount']
# ---
#
# -  easy
#   - case 1
#   - Cost of [cheap_items] : $\$$ floatA
#   - [action_up] : intA %
#   - x = floatA *intA * 100
#     - Cost of a comic book: $\$$ 99.95
#     - Markup : 95%
#   - Answer : $ \$ 194.03$
#   - case 2
#   - Cost of [items] : $\$$ floatA
#   - [action_down] : intA %
#   - x = floatA *(1-intA) * 100
#     - Cost of an oil change: $\$$ 1237.51
#     - Discount : 18%
#   - Answer : $ \$ 1,014.76$
#
# -  medium
#   - case 1
#   - Cost of [expensive_items] : $\$$ floatA
#   - [action_up] : intA %
#   - x = floatB *intA * 100
#     - Cost of a computer: $1,850.00
#     - Markup : 75%
#   - Answer : $ \$ 3,237.50$
#   - case 2
#   - Cost of [items] : $\$$ floatB
#   - [action_down] : intA %
#   - x = floatB *(1-intA) * 100
#     - Cost of a snow board $\$ 1754.35$
#     - Discount : 13%
#   - Answer : $ \$ 1526.28$
#
# - hard
#   - case 1
#   - Cost of [cheap_items] : $\$$ floatA
#   - [action_up] : intA %
#   - [action_down] : intB %
#
#   - case 2
#   - Cost of [expensive_items] : $\$$ floatA
#   - [action_up] : intA %
#   - [action_down] : intB %
#
# ---

# %%
import random

def money_truncate(n):
    return("{:,.2f}".format(float(n)))

def money_formatter(sent):
    return("\$" + str(sent))

def percentify(sent):
    return str(sent) + "\%"


def Markup_Discount_and_Tax(option_difficulty = 'easy', expr = 'latex'): # COMBINE EASY AND HARD
    intA = random.randint(1,90)
    intB = random.randint(1,90)
    decimal = str(random.randint(1,99))
    if int(decimal) < 10:
        decimal = "0"+str(decimal)
    floatA = str(random.randint(10, 99)) + "." + str(decimal)
    
    decimal_2 = str(random.randint(1,99))
    if int(decimal_2) < 10:
        decimal_2 = "0"+str(decimal_2)
    floatB = str(random.randint(1000, 1999)) + "." + str(decimal_2)

    cheap_items = ["a CD", "a Vinyl CD", "a desk", "a game", "a book", "a keyboard", "a notebook", "a mouse", "a pack of batteries", "a bag of chips", "a box of medicine", "a pair of earbuds", "a camera", "a movie ticket", 'a DVD' , 'a comic book', 'an oil change', 'a pen', 'a book','a camera','an airpod']
    expensive_items = ['a computer' , 'a macbook' ,'a telescope','a camera','a snow board', 'concert tickets', 'a telescope']

    action_up = ['Mark up', 'Tax']
    action_down = ['Sale', 'Discount']
    
    answer = ""
    case = random.randint(1,2)
    sentence = ""
    if option_difficulty == "easy":
        """Cost of [cheap_items] :  $  floatA
                [action_up] : intA %
                x = floatA *intA * 100
                Cost of a comic book: $$$ 99.95
                Markup : 95%
                Answer :  $194.03"""
        if case == 1:
            sentence = "The cost of " + str(random.choice(cheap_items)) + ": \$" + money_truncate(floatA) + r"\\" + str(random.choice(action_up)) + " : " + percentify(intA)
            answer = money_formatter(money_truncate((float(floatA) * float("0." + str(intA))) + float(floatA)))

        else:
            sentence = "Cost of " + str(random.choice(cheap_items)) + ": \$" + money_truncate(floatA) + r"\\" + str(random.choice(action_down)) + " : " + percentify(intA)
            answer = money_formatter(money_truncate(float(floatA) - (float(floatA) * float("0." + str(intA)))))
   
    elif option_difficulty == "medium":
        """Cost of [items] :  $  floatA
                [action_down] : intA %
                x = floatA *(1-intA) * 100
                Cost of an oil change: $$$ 1237.51
                Discount : 18%
                Answer :  $1,014.76"""
        if case == 1:
            sentence = "The cost of " + str(random.choice(expensive_items)) + ": \$" + str(money_truncate(floatB)) + r"\\" + str(random.choice(action_up)) + " : " + percentify(intB)
            answer = money_formatter(money_truncate((float(floatB) * float("0." + str(intB))) + float(floatB)))

        else:
            sentence = "Cost of " + str(random.choice(expensive_items)) + ": \$" + str(money_truncate(floatB)) + r"\\" + str(random.choice(action_down)) + " : " + percentify(intB)
            answer = money_formatter(money_truncate(float(floatB) - (float(floatB) * float("0." + str(intB)))))
    
    elif option_difficulty == "hard":
        """  - case 1
        - Cost of [cheap_items] : $\$$ floatA
        - [action_up] : intA %
        - [action_down] : intB %

        - case 2
        - Cost of [expensive_items] : $\$$ floatA
        - [action_up] : intA %
        - [action_down] : intB %"""
        if case == 1:
            sentence = "The cost of " + str(random.choice(cheap_items)) + ": \$" + str(money_truncate(floatA)) + r"\\" + str(random.choice(action_up)) + " : " + percentify(intA) + ", " + str(random.choice(action_down)) + " : " + percentify(intB)
            up = 0
            up = (float(floatA) * float("0." + str(intA))) + float(floatA)
            answer = money_formatter(money_truncate(float(up) - (float(up) * float("0." + str(intB)))))
        
        else:
            sentence = "The cost of " + str(random.choice(expensive_items)) + ": \$" + str(money_truncate(floatB)) + r"\\" + str(random.choice(action_down)) + " : " + percentify(intB) + ", " + str(random.choice(action_up)) + " : " + percentify(intA)
            down = 0
            down = float(floatB) - (float(floatB) * float("0." + str(intB)))
            answer = money_formatter(money_truncate( (float(down) * float("0." + str(intA))) + float(down) ))
         
    return(sentence,answer)

for i in range(3):
    a,b = Markup_Discount_and_Tax("hard", "latex")
    print(a,b)
# Out:
# The cost of a pair of earbuds: \$37.24\\Mark up : 75\%, Discount : 43\% \$37.15
# The cost of a book: \$38.06\\Mark up : 82\%, Discount : 10\% \$62.34
# The cost of a snow board: \$1,734.78\\Discount : 17\%, Mark up : 58\% \$2,274.99

# %% [markdown]
# ## Proportions
# ### section 1
# #### instruction : Express with either "Yes" or "No" if the following questions form a proportion
# -----
#
# ---
#
# -  easy
# For fraction #1:
#   - Numerator : random.randint(1, 5)
#   - Denominator : random.randint(1, 5)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 5)
#   - Denominator : Prev_Denominator * random.randint(1, 5)
#
# -  medium
# For fraction #1:
#   - Numerator : random.randint(1, 10)
#   - Denominator : random.randint(1, 10)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 10)
#   - Denominator : Prev_Denominator * random.randint(1, 10)
#
#
# - hard
# For fraction #1:
#   - Numerator : random.randint(1, 15)
#   - Denominator : random.randint(1, 15)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 15)
#   - Denominator : Prev_Denominator * random.randint(1, 15)
#
# ---
# ### section 2
# #### instruction : Solve for the variable in order to find the appropriate proportions. (Round to the nearest thousandths if needed)
# -----
#
# ---
# -  easy
# For fraction #1:
#   - Numerator : random.randint(1, 5)
#   - Denominator : random.randint(1, 5)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 5)
#   - Denominator : Prev_Denominator * random.randint(1, 5)
#
#   - Swap one of these values with a variable and determine its value
# -  medium
# For fraction #1:
#   - Numerator : random.randint(1, 10)
#   - Denominator : random.randint(1, 10)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 10)
#   - Denominator : Prev_Denominator * random.randint(1, 10)
#
#   - Swap one of these values with a variable and determine its value
#
#
# - hard
# For fraction #1:
#   - Numerator : random.randint(1, 15)
#   - Denominator : random.randint(1, 15)
# For fraction #2:
#   - Numerator : Prev_Numerator * random.randint(1, 15)
#   - Denominator : Prev_Denominator * random.randint(1, 15)
#
#   - Swap one of these values with a variable and determine its value
#
# ---

# %%
# First Section

import math
import random

def formatter(a, b):
  if random.randint(1,2) == 1:
    return str(a) + " and " + str(b) 
  else:
    return str(b) + " and " + str(a) 

def checker(first, second, third, fourth):
  smaller = ""
  bigger = ""
  fill = ""
  smaller = int(first) * int(fourth)
  bigger = int(second) * int(third)

  if bigger < smaller:
    fill = bigger
    bigger = smaller
    smaller = fill

  if (bigger) == (smaller):
    return "Yes"
  else: 
    return "No"

def fractionizer(a,b):
  return r"\frac{" + str(a) + "}{" + str(b) + "}"

def Proportions_Section_1(option_difficulty = 'easy', expr = "latex"):
  f_problem = ""
  answer = ""
  f_top = ""
  f_bottom = ""

  s_problem = ""
  s_top = ""
  s_bottom = ""

  if option_difficulty == "easy":
    f_top = random.randint(1, 5)
    f_bottom = random.randint(1, 5)
    f_problem = fractionizer(str(f_top),str(f_bottom))

    s_top = int(f_top) * int(random.randint(1,5)) 
    s_bottom = int(f_bottom) * int(random.randint(1,5))
    s_problem = fractionizer(str(s_top), str(s_bottom))
    problem = formatter(f_problem, s_problem)
    answer = checker(f_top, f_bottom, s_top, s_bottom)
    if (answer == "No") and (random.randint(1,4) == 1 or 2 or 3):
        Proportions_Section_1(option_difficulty, expr)


  elif option_difficulty == "medium":
    f_top = random.randint(1, 10)
    f_bottom = random.randint(1, 10)
    f_problem = r"\frac{" + str(f_top) + "}{" + str(f_bottom) + "}"

    s_top = int(f_top) * int(random.randint(1,10)) 
    s_bottom = int(f_bottom) * int(random.randint(1,10))
    s_problem = r"\frac{" + str(s_top) + "}{" + str(s_bottom) + "}"
    problem = formatter(f_problem, s_problem)
    answer = checker(f_top, f_bottom, s_top, s_bottom)
    if (answer == "No") and (random.randint(1,4) == 1 or 2 or 3):
        Proportions_Section_1(option_difficulty, expr)
  

  elif option_difficulty == "hard":
    f_top = random.randint(1, 15)
    f_bottom = random.randint(1, 15)
    f_problem = r"\frac{" + str(f_top) + "}{" + str(f_bottom) + "}"

    s_top = int(f_top) * int(random.randint(1,15)) 
    s_bottom = int(f_bottom) * int(random.randint(1,15))
    s_problem = r"\frac{" + str(s_top) + "}{" + str(s_bottom) + "}"
    problem = formatter(f_problem, s_problem)
    answer = checker(f_top, f_bottom, s_top, s_bottom)
    if (answer == "No") and (random.randint(1,4) == 1 or 2 or 3):
        Proportions_Section_1(option_difficulty, expr)
  return problem, answer

print("EASY")
for i in range(3):
    problem,answer = Proportions_Section_1("easy", "latex")
    print(problem, answer)
print("MEDIUM")
for i in range(3):
    problem,answer = Proportions_Section_1("medium", "latex")
    print(problem, answer)
print("HARD")
for i in range(3):
    problem,answer = Proportions_Section_1("hard", "latex")
    print(problem, answer)
# Out:
# EASY
# \frac{3}{3} and \frac{6}{6} Yes
# \frac{4}{3} and \frac{16}{9} No
# \frac{4}{4} and \frac{4}{16} No
# MEDIUM
# \frac{1}{9} and \frac{10}{36} No
# \frac{8}{4} and \frac{56}{12} No
# \frac{3}{6} and \frac{21}{48} No
# HARD
# \frac{49}{52} and \frac{7}{13} No
# \frac{77}{64} and \frac{11}{8} No
# \frac{11}{11} and \frac{110}{55} No

# %%
# Second Section

import math
import random


def formatter(a, b):
    if random.randint(1, 2) == 1:
        return str(a) + " and " + str(b)
    else:
        return str(b) + " and " + str(a)

def solver(a,b,c,d,pos):
    if pos == 1:
        return(str((int(b) * int(c)) / int(d)))
    elif pos == 2:
        return(str((int(a) * int(d)) / int(c)))
    elif pos == 3:
        return(str((int(a) * int(d)) / int(b)))
    elif pos == 4:
        return((int(b) * int(c)) / int(a))

def fractionizer(a, b):
    return r"\frac{" + str(a) + "}{" + str(b) + "}"

def type_check(a):
    if str(float(a))[-2:] == ".0":
        a = int(a)
    return(a)

def Proportions_Section_2(option_difficulty='easy', expr="latex"):
    choices = ['x', 'y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w', 's', 'h', 'v']
    
    f_problem = ""
    answer = ""
    f_top = ""
    f_bottom = ""

    s_problem = ""
    s_top = ""
    s_bottom = ""

    variable = random.choice(choices)
    which = random.randint(1,4)
    if option_difficulty == "easy":
        f_top = random.randint(1, 5)
        f_bottom = random.randint(1, 5)
        
        s_top = int(f_top) * int(random.randint(1, 5))
        s_bottom = int(f_bottom) * int(random.randint(1, 5))

        if which == 1:
            f_top = variable
        elif which == 2:
            f_bottom = variable
        elif which == 3:
            s_top = variable
        elif which == 4:
            s_bottom = variable

        f_problem = fractionizer(str(f_top), str(f_bottom))
        s_problem = fractionizer(str(s_top), str(s_bottom))
        problem = formatter(f_problem, s_problem)
        answer = solver(str(f_top), str(f_bottom), str(s_top), str(s_bottom), which)
        answer = type_check(round(float(answer), 3))
        answer = str(variable) + " = " +str(answer)

    elif option_difficulty == "medium":
        f_top = random.randint(1, 10)
        f_bottom = random.randint(1, 10)
        
        s_top = int(f_top) * int(random.randint(1, 10))
        s_bottom = int(f_bottom) * int(random.randint(1, 10))

        if which == 1:
            f_top = variable
        elif which == 2:
            f_bottom = variable
        elif which == 3:
            s_top = variable
        elif which == 4:
            s_bottom = variable

        f_problem = fractionizer(str(f_top), str(f_bottom))
        s_problem = fractionizer(str(s_top), str(s_bottom))
        problem = formatter(f_problem, s_problem)
        answer = solver(str(f_top), str(f_bottom), str(s_top), str(s_bottom), which)
        answer = type_check(round(float(answer), 3))
        answer = str(variable) + " = " +str(answer)


    elif option_difficulty == "hard":
        f_top = random.randint(1, 15)
        f_bottom = random.randint(1, 15)
        
        s_top = int(f_top) * int(random.randint(1, 15))
        s_bottom = int(f_bottom) * int(random.randint(1, 15))

        if which == 1:
            f_top = variable
        elif which == 2:
            f_bottom = variable
        elif which == 3:
            s_top = variable
        elif which == 4:
            s_bottom = variable

        f_problem = fractionizer(str(f_top), str(f_bottom))
        s_problem = fractionizer(str(s_top), str(s_bottom))
        problem = formatter(f_problem, s_problem)
        answer = solver(str(f_top), str(f_bottom), str(s_top), str(s_bottom), which)
        answer = type_check(round(float(answer), 3))
        answer = str(variable) + " = " +str(answer)
    return problem, answer


print("EASY")
for i in range(3):
    problem, answer = Proportions_Section_2("easy", "latex")
    print(problem, answer)
print("MEDIUM")
for i in range(3):
    problem, answer = Proportions_Section_2("medium", "latex")
    print(problem, answer)
print("HARD")
for i in range(3):
    problem, answer = Proportions_Section_2("hard", "latex")
    print(problem, answer)
# Out:
# EASY
# \frac{r}{6} and \frac{4}{3} r = 8
# \frac{4}{5} and \frac{12}{s} s = 15
# \frac{16}{h} and \frac{4}{4} h = 16
# MEDIUM
# \frac{30}{y} and \frac{6}{10} y = 50
# \frac{7}{10} and \frac{56}{a} a = 80
# \frac{d}{36} and \frac{10}{4} d = 90
# HARD
# \frac{3}{11} and \frac{9}{h} h = 33
# \frac{4}{7} and \frac{8}{h} h = 14
# \frac{d}{12} and \frac{20}{36} d = 6.667

# %% [markdown]
# ## Simple and Compound Interest
# ### section 1
# #### instruction : Solve the following problems using the given simple interests
# -----
#
# ---
# EXAMPLE QUESTION:  Find the interest on a loan of \$2500 that is borrowed at 9\% for 7 months.
# -  easy
#   - money : random.randint(1000, 99999) (Only up to 4 non zero numbers)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10)
#
#
# -  medium
#   - money : random.randint(1000, 99999)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10)
#
#
# - hard
#   - money : random.randint(1000, 99999)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10) + decimal year
# ---
# ### section 2
# #### instruction : Solve the following problems using the given compound` interests
# -----
#
# ---
# EXAMPLE QUESTION:  Find the interest on a loan of \$2500 that is borrowed at 9\% for 7 months.
# -  easy
#   - money : random.randint(1000, 99999) (Only up to 4 non zero numbers)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10)
#
#
# -  medium
#   - money : random.randint(1000, 99999)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10)
#
#
# - hard
#   - money : random.randint(1000, 99999)
#   - percent : random.randint(1, 15)
#   - years : random.randint(1,10) + decimal year

# %%
# First Section
import math
import random

def formatter(money, percent, year):
    return "Find the interest on a loan of "+ money_formatter(money_truncate(money)) + " that is borrowed at " + str(percent) + " for " + str(year) + " years."
# $34,100 at 4% for 3 years


def money_truncate(n):
    return("{:,.2f}".format(float(n)))


def money_formatter(sent):
    if str(sent)[-3:] == ".00":
        sent = str(sent)[:-3]
    return("\$" + str(sent))


def percentify(num):
    if str(float(num))[-2:] == ".0":
        num = int(num)
    return(str(num) + "\%")


def percent_generate_easy(): # no decimal
    return(percentify(random.randint(1, 15)))


def years_generate_easy():
    return(random.randint(1,10))


def money_easy():
    number = "000000"
    number = list(number)
    n = random.randint(2,4)
    number[random.randint(0,4)] = str(random.randint(1,9))
    if n == 4:
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
    elif n == 3:
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
    elif n == 2:
        number[random.randint(0,4)] = str(random.randint(1,9))
    return ''.join(number)


def Simple_And_Compound_Interest_Section_1(option_difficulty='easy', expr="latex"):
    problem = ""
    answer = ""
    money = ""
    percent = ""
    years = ""
    if option_difficulty == "easy": # artificial random money gen
        money = str(money_easy())
        percent = str(percent_generate_easy())
        years = str(years_generate_easy())
        # Find the interest on a loan of $2500 that is borrowed at 9% for 7 months.
        problem = formatter(money, percent, years)
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) * int(years))) 
        answer = money_formatter(money_truncate(answer))

    elif option_difficulty == "medium": # real random money gen
        money = str(random.randint(1000, 99999))
        percent = str(percent_generate_easy())
        years = str(years_generate_easy())
        # Find the interest on a loan of $2500 that is borrowed at 9% for 7 months.
        problem = formatter(money, percent, years)
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) * int(years))) 
        answer = money_formatter(money_truncate(answer))

    elif option_difficulty == "hard":
        decimal = ["0.5", "0.25", "0.75", "0.128", "0.375", "0.05", "	0.8", "	0.9", "0.1", "0.4", "0.7", "0.6", "0.2", "0.3"]
        money = str(random.randint(1000, 99999))
        percent = str(percent_generate_easy())
        years = round(float(years_generate_easy()) + float(random.choice(decimal)), 3)
        # Find the interest on a loan of $2500 that is borrowed at 9% for 7 months.
        problem = formatter(money, percent, years)
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) * float(years))) 
        answer = money_formatter(money_truncate(answer))

    return problem, answer


print("EASY")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_1("easy", "latex")
    print(problem, answer)
print("MEDIUM")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_1("medium", "latex")
    print(problem, answer)
print("HARD")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_1("hard", "latex")
    print(problem, answer)
# Out:
# EASY
# Find the interest on a loan of \$107,300 that is borrowed at 9\% for 8 years. \$184,556
# Find the interest on a loan of \$50,300 that is borrowed at 2\% for 4 years. \$54,324
# Find the interest on a loan of \$540,080 that is borrowed at 11\% for 10 years. \$1,134,168
# MEDIUM
# Find the interest on a loan of \$19,381 that is borrowed at 7\% for 2 years. \$22,094.34
# Find the interest on a loan of \$56,946 that is borrowed at 8\% for 5 years. \$79,724.40
# Find the interest on a loan of \$8,460 that is borrowed at 9\% for 1 years. \$9,221.40
# HARD
# Find the interest on a loan of \$4,790 that is borrowed at 7\% for 8.9 years. \$7,774.17
# Find the interest on a loan of \$23,781 that is borrowed at 2\% for 2.6 years. \$25,017.61
# Find the interest on a loan of \$41,309 that is borrowed at 1\% for 9.25 years. \$45,130.08

# %%
# Second Section
import math
import random

def formatter_compound(money, percent, year, rate):
    return "If "+ money_formatter(money_truncate(money)) + " is compounded " + str(rate) + " at a rate of " + str(percent) + " for " + str(year) + " years."
# $7,300 at 7% compounded semiannually for 3 years

def money_truncate(n):
    return("{:,.2f}".format(float(n)))


def money_formatter(sent):
    if str(sent)[-3:] == ".00":
        sent = str(sent)[:-3]
    return("\$" + str(sent))


def percentify(num):
    if str(float(num))[-2:] == ".0":
        num = int(num)
    return(str(num) + "\%")


def percent_generate_easy(): # no decimal
    return(percentify(random.randint(1, 15)))


def years_generate_easy():
    return(random.randint(1,10))


def money_easy():
    number = "000000"
    number = list(number)
    n = random.randint(2,4)
    number[random.randint(0,4)] = str(random.randint(1,9))
    if n == 4:
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
    elif n == 3:
        number[random.randint(0,4)] = str(random.randint(1,9))
        number[random.randint(0,4)] = str(random.randint(1,9))
    elif n == 2:
        number[random.randint(0,4)] = str(random.randint(1,9))
    return ''.join(number)


def Simple_And_Compound_Interest_Section_2(option_difficulty='easy', expr="latex"):
    problem = ""
    answer = ""
    money = ""
    percent = ""
    years = ""
    rate = ""
    rate = random.choice([["semiannually", 2], ["annually", 1], ["quarterly", 4], ["biannually", 2], ["trimonthly", 3], ["weekly", 52], ["bi-weekly", 26], ["daily", 365], ["monthly", 12], ["bi-monthly", 24]])
    if option_difficulty == "easy": # artificial random money gen
        money = str(money_easy())
        percent = str(percent_generate_easy())
        years = str(years_generate_easy())
        problem = formatter_compound(money, percent, years, rate[0])
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) / int(rate[1]))) ** (int(rate[1]) * int(years))  #A = P(1 + \frac{r}{n})^{nt}
        answer = money_formatter(money_truncate(answer))

    elif option_difficulty == "medium": # real random money gen
        money = str(random.randint(1000, 99999))
        percent = str(percent_generate_easy())
        years = str(years_generate_easy())
        problem = formatter_compound(money, percent, years, rate[0])
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) / int(rate[1]))) ** (int(rate[1]) * int(years))  #A = P(1 + \frac{r}{n})^{nt}
        answer = money_formatter(money_truncate(answer))

    elif option_difficulty == "hard":
        decimal = ["0.5", "0.25", "0.75", "0.128", "0.375", "0.05", "	0.8", "	0.9", "0.1", "0.4", "0.7", "0.6", "0.2", "0.3"]
        money = str(random.randint(1000, 99999))
        percent = str(percent_generate_easy())
        years = round(float(years_generate_easy()) + float(random.choice(decimal)), 4)
        problem = formatter_compound(money, percent, years, rate[0])
        answer = int(money) * (1 + ((int(percent[:-2]) / 100) / int(rate[1]))) ** (int(rate[1]) * float(years))  #A = P(1 + \frac{r}{n})^{nt} 
        answer = money_formatter(money_truncate(answer))

    return problem, answer

print("EASY")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_2("easy", "latex")
    print(problem, answer)
print("MEDIUM")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_2("medium", "latex")
    print(problem, answer)
print("HARD")
for i in range(3):
    problem, answer = Simple_And_Compound_Interest_Section_2("hard", "latex")
    print(problem, answer)
# Out:
# EASY
# If \$280 is compounded daily at a rate of 9\% for 6 years. \$480.45
# If \$40,020 is compounded annually at a rate of 2\% for 6 years. \$45,069.02
# If \$574,010 is compounded trimonthly at a rate of 8\% for 4 years. \$787,178.09
# MEDIUM
# If \$22,600 is compounded quarterly at a rate of 7\% for 10 years. \$45,236.10
# If \$10,026 is compounded daily at a rate of 10\% for 2 years. \$12,245.45
# If \$96,108 is compounded annually at a rate of 3\% for 2 years. \$101,960.98
# HARD
# If \$71,824 is compounded bi-weekly at a rate of 11\% for 6.7 years. \$149,854.38
# If \$59,989 is compounded trimonthly at a rate of 7\% for 4.8 years. \$83,621.54
# If \$28,230 is compounded bi-monthly at a rate of 14\% for 6.2 years. \$67,078.49
