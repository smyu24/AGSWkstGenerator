# %% [markdown]
# Seed Rule
#
# [2, 1, 5, 10, 20, 3, 5, 10, 20]
#
# First digit = "Total number of Section"
# - There is two different section in this request
# ---
# Each Section has a total of 4 digit.
# * [1, 5, 10, 20]
# - 1 = Difficulty -> [Easy=1, Medium=2, Hard=3]
# - 5 = Number of problem -> User wants to create 5 problems
# - 10, 20 = Min and Max
#
# IF the user clicks the auto generator button then minimum and maximum values will turn into 0.
# - Ex. [1, 5, 0, 0] | When the python code detects both are equal to zero then bring the default values and replace them.

# %% [markdown]
# # **Part 2 Number Theory**

# %% [markdown]
# ##Divisibility and Factors
# ---
# ###Section 1
# #### **instruction** : State if the first number is divisible by the second number.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
#
# - Easy
#   - 2 digits (1-99) by 1 digit (1-10)
#   - 92 by 3
# - medium
#   - 2 digits(100-999) by 2 digits (1-20)
#   - 729 by 9
#   - 837 by 13
# - hard
#   - 4 digits(1000-9999) by 2 digits (1-30)
#   - 7298 by 15
#   - 7298 by 27
#
# ###Section 2
# #### **instruction** : Each number is divisible by which of the following: 2, 3, 5, 6, 9, 10?
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
# Can these numbers divide this number?
#
# - Easy
#   - 2 digits (0-99) by divisibility for 3 numbers (2-10)
#   - Is $ 88 $ divisible by $ 2 , 4 , 7 $?
#
# - Medium
#   - 2 digits(50-500) by 5 different numbers (2-20)
#   - Is $ 729 $ divisible by $ 2 , 5 , 9 , 10 , 15  $
#   - Is $ 635 $ divisible by $ 3 , 5 , 10 , 12 , 13 $
#
# - Hard
#   - 3 digits($500-999$) by $7$ different numbers (2-20)
#   - Is $ 999 $ by $ 2, 3, 5, 6, 7, 13, 23 $ ?
#   - Is $ 854 $ by $ 3, 4, 7, 10, 12, 14, 19 $ ?

# %%
#First section
import math
import random

def latexify(input, option="inline"):
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

def Divisibility_And_Factors_Section_1(option_difficulty='easy', expr='latex'):
  problemsets = ""
  temp_problem = []
  answerset = []
  temp = ""

  if option_difficulty == "easy":
    dividing_number = random.randint(2,10)
    problemsets = random.randint(10, 25)

  elif option_difficulty == "medium":
    dividing_number = random.randint(2,15)
    problemsets = random.randint(25, 100)

  elif option_difficulty == "hard":
    dividing_number = random.randint(2,23)
    problemsets = random.randint(90, 999)
  if expr == 'latex':
    temp_problem = latexify(str(problemsets)), " by ", latexify(str(dividing_number))
  else:
    temp_problem = str(problemsets), " by ", str(dividing_number)

  temp_problem = ''.join(temp_problem)

    #answer generation...
  temp = problemsets/dividing_number
  if temp % 1 != 0:
    answerset = "No"
  else:
    answerset = "Yes"
  
  return(temp_problem, answerset)
  
print('------------------------------------------------------------------')
problem, answer = Divisibility_And_Factors_Section_1("easy", "latex")
print(problem, "\n", answer)
problem, answer = Divisibility_And_Factors_Section_1("medium", "latex")
print(problem, "\n", answer)
problem, answer = Divisibility_And_Factors_Section_1("hard", "latex")
print(problem, "\n", answer)
# Out:
# ------------------------------------------------------------------
# $21$ by $5$
#  No
# $84$ by $10$
#  No
# $514$ by $23$
#  No

# %%
"""#First section
import math
import random

def latexify(input, option="inline"):
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

def Divisibility_And_Factors_Section_1(option_difficulty='easy', expr='latex'):
  problemsets = ""
  temp_problem = []
  answerset = []
  temp = ""

  if option_difficulty == "easy":
    dividing_number = random.randint(2,10)
    problemsets = random.randint(10, 25)

  elif option_difficulty == "medium":
    dividing_number = random.randint(2,15)
    problemsets = random.randint(25, 100)

  elif option_difficulty == "hard":
    dividing_number = random.randint(2,23)
    problemsets = random.randint(90, 999)
  if expr == 'latex':
    temp_problem = latexify(str(problemsets)), " by ", latexify(str(dividing_number))
  else:
    temp_problem = str(problemsets), " by ", str(dividing_number)

  temp_problem = ''.join(temp_problem)

    #answer generation...
  temp = problemsets/dividing_number
  if temp % 1 != 0:
    answerset = "No"
  else:
    answerset = "Yes"
  
  return(temp_problem, answerset)
  
print('------------------------------------------------------------------')
problem, answer = Divisibility_And_Factors_Section_1("easy", "latex")
print(problem, "\n", answer)
problem, answer = Divisibility_And_Factors_Section_1("medium", "latex")
print(problem, "\n", answer)
problem, answer = Divisibility_And_Factors_Section_1("hard", "latex")
print(problem, "\n", answer)
"""

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

#Second Section
import math
import random

def Divisibility_And_Factors_Section_2(option_difficulty = 'easy', expr ='latex' ):
  problemsets = ""
  answerset = []
  temp = []
  header_numbers = []

  if option_difficulty == "easy":
    problemsets = random.randint(1, 99)
    for i in range(3):
        header_numbers.insert(i, random.randint(1,10))

  elif option_difficulty == "medium":
    problemsets = random.randint(50, 500)
    for i in range(5):
        header_numbers.insert(i, random.randint(1,10))

  elif option_difficulty == "hard":
    problemsets = random.randint(500, 9999)
    for i in range(7):
        header_numbers.insert(i, random.randint(1,10))
  for i in header_numbers:
    if i not in temp:
        temp.append(i)

  header_numbers = temp
  header_numbers.sort()
    #answer generation...
  for i in range(len(header_numbers)):
      if problemsets/header_numbers[i] % 1 == 0:
          if expr == 'latex':
            answerset.append(latexify(str(header_numbers[i])))
          else: 
            answerset.append((str(header_numbers[i])))

  if len(answerset) == 0:
    answerset.append("None")
  if expr == 'latex':
    for i in range(len(header_numbers)):
        header_numbers[i] = latexify(header_numbers[i])   
    problemsets = latexify(problemsets)
  
  return(', '.join(str(v) for v in header_numbers), problemsets, ', '.join(str(v) for v in answerset))

header, problem, answer = Divisibility_And_Factors_Section_2("easy", 'latex')
print(header, '\n', problem, "\n", answer)
# Out:
# $7$, $9$
#  $56$
#  $7$

# %% [markdown]
# ##Factoring numbers
#
# ### Section 1
# ---
# #### **instruction** : List all possible factors of each.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
#
# - Easy
#   - 2 digit (10-50)
#   - $ 22 $
#   - Answers : $ 1 , 2 , 11, 22$
# - Medium
#   - 2 digit (50-99)
#   - $ 88 $
#   - Answers : $ 1 , 2 , 4 , 8 , 11 , 22 , 44 , 88$
#
#
# ---
# ### Section 2
# #### **instruction** : List all prime factors of each.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
# - Easy
#   - 2 digit (10-50)
#   - $ 22 $
#   - Answers : $ 2 , 11 $
# - Medium
#   - 2 digit (50-99)
#   - $ 88 $
#   - Answers : $ 2^3 , 11 $

# %%
#First Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'


def Factoring_Num_Section_1(option_difficulty = 'easy', expr = 'latex', option_min = 10, option_max = 50):
  problemsets = ""
  answerset = []
  temp = []

  if option_difficulty == "easy":
    problemsets = random.randint(10, 50)

  elif option_difficulty == "medium" or option_difficulty == "hard":
    problemsets = random.randint(50, 99)

    #answer generation...
  for i in range(1, int(problemsets / 2) + 1):
    if problemsets % i == 0:
      if i not in temp:
        temp.append(i)
      if int(problemsets/i) not in temp:
        temp.append(int(problemsets/i))
  temp.sort()  
  if expr == 'latex':
    for i in range(len(temp)):
        temp[i] = latexify(temp[i])
    problemsets = latexify(problemsets)
  return(problemsets, ', '.join(str(i) for i in temp)) # nothing yet

problem,answer = Factoring_Num_Section_1("medium", 'latex')
print(problem, "\n", answer, "\n")
# Out:
# $71$
#  $1$, $71$

# %%
#Second Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors

def Factoring_Num(option_difficulty = 'easy', expr = 'latex'):
  problemsets = ""
  answerset = []
  temp = []
  unique = []

  if option_difficulty == "easy":
    problemsets = random.randint(10, 50)

  elif option_difficulty == "medium" or option_difficulty == "hard":
    problemsets = random.randint(50, 99)

    #answer generation...
  temp = prime_factors(problemsets)

  for i in temp:
    if i not in unique:
      unique.append(i)

  for i in unique:
    if temp.count(i) != 1:
      answerset.append(str(i) + "^" + str(temp.count(i)))
    else:
      answerset.append(str(i))
  if expr == 'latex': 
    return(latexify(problemsets), ', '.join(latexify(i) for i in answerset))
  else:
    return(problemsets, ', '.join(str(i) for i in answerset))
problem, answer = Factoring_Num("medium", "latex")
print(problem, "\n", answer ,"\n")
# Out:
# $69$
#  $3$, $23$

# %% [markdown]
# ## Listing monomials
#
# ### Section 1
# ---
# #### **instruction** : List all possible prime factors of each.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
# - Easy
#   - generates a number between $10$ - $40$
#   - problem : $ 32x $
#   - Answers : $ 2 \cdot 2 \cdot 2 \cdot 2 \cdot 2 \cdot 2 \cdot x$
# - Medium
#   - generates a number between $40$ - $70$
#   - one ~ two variables, up to max power of $ 4 $
#   - problem : $ 52 x^2 y^3 $
#   - Answers : $ 2 \cdot 2 \cdot 13 \cdot x \cdot x \cdot y \cdot y \cdot y$
# - Hard
#   - generate a number between $70 - 100$
#   - two ~ three variables, up to max power of $ 7 $
#   - problem : $ 72 x^5 y^2 z$
#   - Answers : $ 2 \cdot 2 \cdot 2 \cdot 3 \cdot 3 \cdot x \cdot x \cdot x \cdot x \cdot x \cdot y \cdot y \cdot z $
#
# ### Section 2
# ---
# #### **instruction** : List all prime factors of each, with the use of exponents.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
#
# - Easy
#   - generates a number between $10$ - $40$
#   - one variable, up to max power of $ 2 $
#   - Problem : $ 32x $
#   - Answers : $ 2^5 \cdot x$
# - Medium
#   - generates a number between $40$ - $70$
#   - one ~ two variables, up to max power of $ 3 $
#   - Problem : $ 52 x^2 y^3 $
#   - Answers : $ 2^2 \cdot 13 \cdot x^2 \cdot y^3$
# - Hard
#   - generate a number between 70 - 100
#   - two ~ three variables, up to max power of $ 7 $
#   - Problem : $ 72 x^5 y^2 z$
#   - Answers : $ 2^3 \cdot 3^2 \cdot x^5 \cdot y^2 \cdot z $

# %%
 #First Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors


def count_var(variable):
    unique = []
    answerset = []
    for i in variable:
        if i not in unique:
            unique.append(i)
    for i in unique:
        if variable.count(i) != 1:
            answerset.append(str(i) + "^" + str(variable.count(i)))
        else:
            answerset.append(str(i))
    return(''.join(str(i) for i in answerset))


def Factoring_Monomials_Section_1(option_difficulty = 'easy', expr = 'latex'):
    problemsets = ""
    answerset = []
    number = 0
    variable = []
    choices = ['x','y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w']
    add = []
    mult = 0
    temp = []
    place_holder = []
    switch = False

    if option_difficulty == "easy":
        number = random.randint(10, 40)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        variable = random.choice(choices)
        for i in range(random.randint(1, 2)):
            place_holder.append(variable)

    elif option_difficulty == "medium":
        number = random.randint(40, 70)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        for i in range(random.randint(1, 2)):
          variable = random.choice(choices)
          for i in range(random.randint(1, 4)):
            place_holder.append(variable)

    elif option_difficulty == "hard":
        number = random.randint(70, 100)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        for i in range(random.randint(2, 3)):
          variable = random.choice(choices)
          for i in range(random.randint(1, 7)):
            place_holder.append(variable)

    #answer generation...
    problemsets = prime_factors(number)
    problemsets = problemsets + place_holder
    if expr == 'latex':
        answerset = ', '.join(latexify(i) for i in problemsets)
    else:
        answerset = ', '.join(str(i) for i in problemsets)
    number = str(number) + count_var(place_holder)
    if expr == 'latex':
        return(latexify(number), answerset)
    else:
        return(number, answerset)
problem, answer = Factoring_Monomials_Section_1("hard", "latex")
print(problem,"\n", answer,"\n")
# Out:
# $70zd^4q^7$
#  $2$, $5$, $7$, $z$, $d$, $d$, $d$, $d$, $q$, $q$, $q$, $q$, $q$, $q$, $q$

# %%
#Second Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'

def prime_factors(n):
    i = 2
    factors = []
    while i * i <= n:
        if n % i:
            i += 1
        else:
            n //= i
            factors.append(i)
    if n > 1:
        factors.append(n)
    return factors


def count_var(variable, format):
    unique = []
    answerset = []
    a = ""
    for i in variable:
        if i not in unique:
            unique.append(i)
    for i in unique:
        if variable.count(i) != 1:
            answerset.append(str(i) + "^" + str(variable.count(i)))
        else:
            answerset.append(str(i))
    if format == True:
        for i in range(len(answerset)):
            if i == 0:
                a = a + answerset[i]
            else:
                a = a + ", " + answerset[i]
        return(a)
    else:
        return(''.join((str(b) for b in answerset)))


def Factoring_Monomials_Section_2(option_difficulty = 'easy', expr = 'latex'):
    problemsets = ""
    answerset = ""
    number = 0
    variable = []
    choices = ['x','y', 'a', 'b', 'z', 'p', 't', 'q', 'k', 'u', 'r', 'd', 'w']
    temp = []
    place_holder = []
    switch = False

    if option_difficulty == "easy":
        number = random.randint(10, 40)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        variable = random.choice(choices)
        for i in range(random.randint(1, 2)):
            place_holder.append(variable)

    elif option_difficulty == "medium":
        number = random.randint(40, 70)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        for i in range(random.randint(1, 2)):
          variable = random.choice(choices)
          for i in range(random.randint(1, 4)):
            place_holder.append(variable)

    elif option_difficulty == "hard":
        number = random.randint(70, 100)
        for i in range(2, number):
            if(number % i) == 0:
                switch = True
        if switch != True:
            number = random.randint(10, 40)
        for i in range(random.randint(2, 3)):
          variable = random.choice(choices)
          for i in range(random.randint(1, 7)):
            place_holder.append(variable)

    #answer generation...
    problemsets = prime_factors(number)
    answerset = count_var(problemsets, True)
    answerset = answerset + ", " + count_var(place_holder, True)
    if expr == 'latex':
        answerset = latexify(answerset)
    number = str(number) + count_var(place_holder, False)
    if expr == 'latex':
        return(latexify(number), answerset)
    else:
        return(number, answerset)
problem, answer = Factoring_Monomials_Section_2("hard", "latex")
print(problem,"\n", answer,"\n")
# Out:
# $88bk^7$
#  $2^3, 11, b, k^7$

# %% [markdown]
# ##Greatest common factors
# ### Section 1 (all numerals)
# #### Factor two monomials.
# #### **instruction** : Factor the two monomials into greatest common factors.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
# Parameters: rand_range_min , rand_range_max , max_variable_power ,max_num_variable
# - Easy
#   - A number (2-10) * (2-10)
#   - $ 80 , 60 $
#   - Answers : $ 20 $
# - Medium
#   - A number (10-20) * (10-20)
#   - $ 80 , 60 $
#   - Answers : $ 20 $
# - Hard
#   - A number (15-25) * (15-25)
#   - $ 80 , 100 $
#   - Answers : $ 20 $
#
#
# ### Section 2 (numerals and variables)
# #### Factor two monomials.
# #### **instruction** : Factor the two monomials into greatest common factors.
# #### option
# ---
# 1. Drop down - E/M/H
# 2. Total problems
# ---
# - Easy
#   - A number (2-10) * (2-10) && up to two different variables (each to max power of 2)
#   - $ 80x , 60x^2 $
#   - Answers : $ 20x $
# - Medium
#   - A number (10-20) * (10-20) && up to three different variables (each to max power of 3)
#   - $ 80xy^2 , 60x^2y^4 $
#   - Answers : $ 20xy^2 $
# - Hard
#   - A number (15-25) * (15-25) && 3 variables to max power of 7
#   - $ 80xy^2z^6 , 100x^2y^4z^4 $
#   - Answers : $ 20xy^2z^4 $

# %%
#First Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'


def Greatest_Common_Factor_Section_1(option_difficulty = 'easy', expr = 'latex'):
    problemsets = []
    answerset = []
    holder = []
    temp = []
    gcf = 0

    if option_difficulty == "easy":
        problemsets = random.randint(2, 10)

    elif option_difficulty == "medium":
        problemsets = random.randint(10, 20)

    elif option_difficulty == "hard":
        problemsets = random.randint(15, 25)

    # answer generation...
    for i in range(1, int(problemsets / 2) + 1):
        if problemsets % i == 0:
            if i not in temp:
                temp.append(i)
            if int(problemsets/i) not in temp:
                temp.append(int(problemsets / i))
    holder = random.choice(temp[1:])
    if option_difficulty == "easy":
        answerset.append(holder * random.randint(2, 10))
        answerset.append(holder * random.randint(2, 10))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(2, 10))
    elif option_difficulty == "medium":
        answerset.append(holder * random.randint(10, 20))
        answerset.append(holder * random.randint(10, 20))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(10, 20))
    elif option_difficulty == "hard":
        answerset.append(holder * random.randint(15, 25))
        answerset.append(holder * random.randint(15, 25))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(15, 25))
    gcf = math.gcd(answerset[0], answerset[1])
    if expr == 'latex':
        return(', '.join(latexify(t) for t in answerset), latexify(gcf))
    else:
        answerset = str(answerset[0]) + ", " + str(answerset[1])
        return(answerset , gcf)

problem, answer = Greatest_Common_Factor_Section_1("hard", "latex")
print(problem, " --- ", answer)
# Out:
# $500$, $525$  ---  $25$

# %%
#Second Section

import math
import random

def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'


def count_var_f(variable, format):
    unique = []
    answerset = []
    for i in variable:
        if i not in unique:
            unique.append(i)
    for i in unique:
        if variable.count(i) != 1:
            answerset.append(str(i) + "^" + str(variable.count(i)))
        else:
            answerset.append(str(i))
    if format == True:
        return(answerset)
    else:
        return(''.join((str(b) for b in answerset)))


def generate_variables(option_difficulty):    
    variable = []
    choices = ['x', 'y', 'z', 't', 'u', 'r']
    filler = ""
    one = random.randint(1, len(choices) - 2)
    two = random.randint(0, one - 1)
    three = random.randint(one + 1, len(choices) - 1)

    if option_difficulty == "easy":
        for i in range(2):
            mult = [True, False]
            picked = random.randint(1, 2)
            if i == 0 and random.choice(mult) == True:
                variable.append(choices[one] * picked)
            elif i == 1 and random.choice(mult) == True:
                variable.append(choices[two] * picked)

    elif option_difficulty == "medium":
        for i in range(3):
            mult = [True, False]
            picked = random.randint(1, 3)
            if i == 0 and random.choice(mult) == True:
                variable.append(choices[one] * picked)
            elif i == 1 and random.choice(mult) == True:
                variable.append(choices[two] * picked)
            elif i == 2:
                variable.append(choices[three] * picked)

    elif option_difficulty == "hard":
        for i in range(3):
            picked = random.randint(1, 7)
            if i == 0:
                variable.append(choices[one] * picked)
            elif i == 1:
                variable.append(choices[two] * picked)
            elif i == 2:
                variable.append(choices[three] * picked)

    return(variable)


def overlapping_var(first, second):
    answer = ""
    taken_1 = ""
    taken_2 = ""
    for i in range(len(first)):
        for t in range(len(second)):
            taken_1 = first[i]
            taken_2 = second[t]
            if taken_1[:1] == taken_2[:1]:
                if taken_1[1:2] == '^' and taken_2[1:2] == '^':
                    if taken_1[2:] >= taken_2[2:]:
                        answer = answer + str(taken_2)
                    else:
                        answer = answer + str(taken_1)
                else:
                    answer = answer + str(taken_1[:1])
    if answer != 'None':
        return(answer)
    else:
        return('')

def Greatest_Common_Factor_Section_2(option_difficulty = 'easy', expr = 'latex'):
    problemsets = []
    answerset = []
    holder = []
    temp = []
    gcf = 0

    if option_difficulty == "easy":
        problemsets = random.randint(2, 10)

    elif option_difficulty == "medium":
        problemsets = random.randint(10, 20)

    elif option_difficulty == "hard":
        problemsets = random.randint(15, 25)

    # answer generation...
    for i in range(1, int(problemsets / 2) + 1):
        if problemsets % i == 0:
            if i not in temp:
                temp.append(i)
            if int(problemsets/i) not in temp:
                temp.append(int(problemsets / i))
    holder = random.choice(temp[1:])
    if option_difficulty == "easy":
        answerset.append(holder * random.randint(2, 10))
        answerset.append(holder * random.randint(2, 10))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(2, 10))
    elif option_difficulty == "medium":
        answerset.append(holder * random.randint(10, 20))
        answerset.append(holder * random.randint(10, 20))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(10, 20))
    elif option_difficulty == "hard":
        answerset.append(holder * random.randint(15, 25))
        answerset.append(holder * random.randint(15, 25))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(15, 25))
    gcf = math.gcd(answerset[0], answerset[1])

    generated_1 = ''.join(generate_variables(option_difficulty))
    generated_2 = ''.join(generate_variables(option_difficulty))
    list(generated_1)
    list(generated_2)
    first = str(count_var_f(generated_1, False))
    second = str(count_var_f(generated_2, False))
    gcf = str(gcf) + str(overlapping_var(count_var_f(generated_1, True), count_var_f(generated_2, True)))
    answerset[0] = '{}{}'.format(str(answerset[0]), first)
    answerset[1] = '{}{}'.format(str(answerset[1]), second)
    # manipulate the answerset here [0], [1] (add variabels)

    if expr == 'latex':
        return(', '.join(latexify(t) for t in answerset), latexify(gcf))
    else:
        answerset = str(answerset[0]) + ", " + str(answerset[1])
        return(answerset , gcf)

problem, answer = Greatest_Common_Factor_Section_2("hard", "latex")
print(problem, " --- ", answer)
# Out:
# $264u^2y^6r$, $216u^3y^2r^7$  ---  $24u^2y^2r$

# %% [markdown]
# ##Least Common Multiple
# ### Section 1
# #### Find the LCM of each.
# Parameters: rand_range_min , rand_range_max , max_variable_power ,max_num_variable
# - Easy
#   - A generates a number from 2 to 10
#   - $ 80x , 60x^2 $
#   - Answers : $ 20x $
# - Medium
#   - A number (40-70) + 1 ~ 2 variable to max power of 4
#   - $ 80xy^2 , 60x^2y^4 $
#   - Answers : $ 20xy^2 $
# - Hard
#   - A number (70-100) + 3 variables to max power of 7
#   - $ 80xy^2z^6 , 100x^2y^4z^4 $
#   - Answers : $ 20xy^2z^4 $

# %%
# First Section

import math
import random


def latexify(input, option="inline"):
    input = str(input)
    if option == "inline":
        return r"$" + input + r"$"
    else:
        return '\[' + input + '\]'


def Find_LCM(one, two):
   lcm = 0
   greater = 0
   if one > two:
       greater = one
   else:
       greater = two

   while(True):
       if ((greater % one == 0) and (greater % two == 0)):
           LCM = greater
           break
       greater += 1
   return LCM


def Least_Common_Multiple(option_difficulty = 'easy', expr = 'latex'):
    problemsets = []
    answerset = []
    holder = []
    temp = []
    lcm = 0

    if option_difficulty == "easy":
        problemsets = random.randint(2, 10)

    elif option_difficulty == "medium":
        problemsets = random.randint(10, 20)

    elif option_difficulty == "hard":
        problemsets = random.randint(15, 25)

    # answer generation...
    for i in range(1, int(problemsets / 2) + 1):
        if problemsets % i == 0:
            if i not in temp:
                temp.append(i)
            if int(problemsets/i) not in temp:
                temp.append(int(problemsets / i))
    holder = random.choice(temp[1:])
    if option_difficulty == "easy":
        answerset.append(holder * random.randint(2, 10))
        answerset.append(holder * random.randint(2, 10))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(2, 10))
    elif option_difficulty == "medium":
        answerset.append(holder * random.randint(10, 20))
        answerset.append(holder * random.randint(10, 20))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(10, 20))
    elif option_difficulty == "hard":
        answerset.append(holder * random.randint(15, 25))
        answerset.append(holder * random.randint(15, 25))
        if(answerset[0] == answerset[1]):
            answerset.pop(1)
            answerset.append(holder * random.randint(15, 25))
    lcm = Find_LCM(answerset[0], answerset[1])
    if expr == 'latex':
        return(latexify(str(answerset[0])) + ", " + latexify(str(answerset[1])), latexify(lcm))
    else:
        return(str(answerset[0]) + ", " + str(answerset[1]), lcm)


problem, answer = Least_Common_Multiple("easy", "latex")
print(problem," --- ",answer)
# Out:
# $36$, $18$  ---  $36$
